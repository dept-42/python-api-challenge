# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st 
import os
import random
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
print(f"weather api key: {weather_api_key}")
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# weather api key: 99d9c9c3906f8432242946870f7f1b5c

# %%
print(f"cwd: {os.getcwd()}")
# Out:
# cwd: /Users/wayne.mitchell/Documents/NU/python-api-challenge/WeatherPy

# %%
os.listdir()
# Out:
# ['VacationPy.ipynb',
#  'output_data',
#  '__pycache__',
#  'WeatherPy.ipynb',
#  '.ipynb_checkpoints',
#  'api_keys.py']

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)


# check for about equal number of cities in northern and southern hemisphere
# and total > 1500
lat_lngs_list = list(zip(lats, lngs))

northCount = 0
southCount = 0
for i in lat_lngs_list:
    if i[0] >= 0:
        northCount += 1
    else:
        southCount += 1
print(f"northCount: {northCount}, southCount: {southCount} total: {northCount + southCount}")
# Out:
# northCount: 754, southCount: 746 total: 1500

# %%
# create bins of latitude

# make a lat, lng dict for later recovery of lan values
# and a lat list for input to 'cut'
lat_lng_dict = {}
lat_list = []
for i in lat_lngs_list:
    lat = i[0]
    lng = i[1]
    lat_lng_dict[round(lat,3)] = round(lng,3)
    lat_list.append(round(lat,3))
    
s_75_90 = []
s_60_75 = []
s_45_60 = []
s_30_45 = []
s_15_30 = []
s_0_15  = []
n_0_15  = []
n_15_30 = []
n_30_45 = []
n_45_60 = []
n_60_75 = []
n_75_90 = []


#make latitude bins of 15 degrees
for lat in lat_list:
    if lat <= -90.0:
        s_75_90.append(lat)
        
    elif lat <= -75.0:
        s_60_75.append(lat)
        
    elif lat <= -60.0:
        s_45_60.append(lat) 
        
    elif lat <= -45.0:
        s_30_45.append(lat)
        
    elif lat <= -30.0:
        s_15_30.append(lat) 
        
    elif lat <= -15.0:
        s_0_15.append(lat)
        
    elif lat <= 15.0:
        n_0_15.append(lat)
        
    elif lat <= 30.0:
        n_15_30.append(lat)  
        
    elif lat <= 45.0:
        n_30_45.append(lat)
        
    elif lat <= 60.0:
        n_45_60.append(lat)
        
    elif lat <= 75.0:
        n_60_75.append(lat)
        
    else:
        n_75_90.append(lat)
        
latitude_bands = [s_75_90, \
                  s_60_75, \
                  s_45_60, \
                  s_30_45, \
                  s_15_30, \
                  s_0_15, \
                  n_0_15, \
                  n_15_30, \
                  n_30_45, \
                  n_45_60, \
                  n_60_75, \
                  n_75_90]
print(len(latitude_bands))
print(f"count of s_75_90: {len(s_75_90)}")
print(f"count of s_60_75: {len(s_60_75)}")
print(f"count of s_45_60: {len(s_45_60)}")
print(f"count of s_30_45: {len(s_30_45)}")
print(f"count of s_15_30: {len(s_15_30)}")
print(f"count of s_0_15: {len(s_0_15)}")
print(f"count of n_0_15: {len(n_0_15)}")
print(f"count of n_15_30: {len(n_15_30)}")
print(f"count of n_30_45: {len(n_30_45)}")
print(f"count of n_45_60: {len(n_45_60)}")
print(f"count of n_60_75: {len(n_60_75)}")
print(f"count of n_75_90: {len(n_75_90)}")

#print(latitude_bands)
# Out:
# 12
# count of s_75_90: 0
# count of s_60_75: 119
# count of s_45_60: 127
# count of s_30_45: 147
# count of s_15_30: 103
# count of s_0_15: 122
# count of n_0_15: 266
# count of n_15_30: 128
# count of n_30_45: 132
# count of n_45_60: 98
# count of n_60_75: 121
# count of n_75_90: 137

# %%
# Discard extreme south, count of s_75_90: 0, nothing there, leaves 11 bands.
# collect 49 random latitudes from each list (49 X 11 = 501, so adjust to 501 from 500)

# remove first empty sublist
print(len(latitude_bands))
latitude_bands.pop(0)
print(len(latitude_bands))
latitude_bands_reduced = []
sample_size = 49
city_count = 0
loop_index = 1
cities = []
while city_count < 500:
    print(f"loop index: {loop_index}")
    loop_index += 1
    for lat_band in latitude_bands:
        #print(lat_band)
        if len(lat_band) < sample_size:
            lat_bandr = lat_band
        else:
            lat_bandr =  random.sample(lat_band, sample_size)
            #print(type(lat_bandr))
            #print(lat_band)
            #print(f"number of lats now: {len(lat_band)}")

        # trim to 49 elements
        if len(lat_bandr) > 49:
            lat_bandr = random.sample(lat_bandr, 49)
            
        latitude_bands_reduced.append(list(lat_bandr))
        
    print(f"elements  in latitude_bands_reduced: {len(latitude_bands_reduced)}")
    type(latitude_bands_reduced)
        
    # Empty list for holding the cities names
    
    for lat_band in latitude_bands_reduced:
        #print(type(lat_band))
        for lat in lat_band:
            #print(lat)
            lng = lat_lng_dict[lat]
            city = citipy.nearest_city(lat, lng).city_name
            if city not in cities:
                cities.append(city)
    city_count = len(cities)

#cities = random.sample(cities , 500)
# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
print(cities)
# Out:
# 12
# 11
# loop index: 1
# elements  in latitude_bands_reduced: 11
# loop index: 2
# elements  in latitude_bands_reduced: 22
# loop index: 3
# elements  in latitude_bands_reduced: 33
# loop index: 4
# elements  in latitude_bands_reduced: 44
# loop index: 5
# elements  in latitude_bands_reduced: 55
# Number of cities in the list: 506
# ['edinburgh of the seven seas', 'port-aux-francais', 'ushuaia', 'bredasdorp', 'adamstown', 'puerto natales', 'port elizabeth', 'waitangi', 'grytviken', 'blackmans bay', 'punta arenas', 'hermanus', 'albany', 'port alfred', 'papatowai', 'invercargill', 'margaret river', 'east london', 'constantia', 'chonchi', 'quellon', 'stanley', 'sarmiento', 'rio grande', 'plettenberg bay', 'lebu', 'port macquarie', 'sale', 'afaahiti', 'healesville', 'constitucion', 'el trebol', 'kingston', 'santa elena', 'mar del plata', 'pozo del molle', 'ancud', 'wynyard', 'avarua', 'thames', 'tranovaho', "port saint john's", 'newnham', 'tsiombe', 'tolanaro', 'arraial do cabo', 'laguna', 'yeppoon', 'luderitz', 'west island', 'taltal', 'lubango', 'shakawe', 'goianesia', 'belmonte', 'alice springs', 'moranbah', 'carnarvon', 'prado', 'ondjiva', 'saint-paul', 'ambodifotatra', 'cairns city', 'saint-philippe', 'broken hill', 'port mathurin', 'coquimbo', 'tamarin', 'emerald', 'callao', 'kununurra', 'flying fish cove', 'swakopmund', 'puerto ayora', 'inirida', 'moroto', 'antsiranana', 'mejit', 'pamandzi', 'huanuco', 'nabire', 'vingt cinq', 'georgetown', 'sao raimundo nonato', 'taiohae', 'ugoofaaru', 'yaren', 'olinda', 'fale old settlement', 'hell-ville', 'jamestown', 'buala', 'sinabang', 'palikir - national government center', 'mili', 'ibimirim', 'malango', "hayma'", 'mabaruma', 'gaalkacyo', 'kirakira', 'bamboo flat', 'cabo san lucas', 'flores costa cuca', 'rongelap', 'san patricio', 'mukah', 'acarau', 'puerto armuelles', 'tabou', 'caleta de carquin', 'bima', 'yanam', 'bubaque', 'tanjung selor', 'tual', 'tekkali', 'jiaojiang', 'wailua homesteads', 'ribeira grande', 'lihue', 'heroica guaymas', 'utrik', 'enewetak', 'zouerate', 'vientiane', 'nishinoomote', 'lompoc', 'hawaiian paradise park', 'jaltenango de la paz', 'huanggang', 'lashio', 'awjilah', 'port lavaca', 'ubari', 'pathein', 'pedro escobedo', 'ad dilam', 'chhindwara', 'mukalla', 'tangping', 'pavuluru', 'bardai', 'san pedro', 'as sulayyil', 'pasuquin', 'saipan', 'gopalpur', 'hamilton', 'am djarass', 'remire-montjoly', 'kodiak', 'yuzhno-kurilsk', 'pratt', 'jinan', 'mary', 'loveland', 'al azraq ash shamali', 'haiku-pauwela', 'arrifes', 'conception bay south', 'kincardine', 'praia da vitoria', 'kill devil hills', 'petropavlovsk-kamchatsky', 'susanville', 'buarcos', 'brookings', 'boryeong', 'shofirkon shahri', 'montecatini-terme', 'moab', 'eureka', 'fortuna', 'turkmenabat', 'al kut', 'ohara', 'faro', 'bridgewater', 'deqen', 'pachino', 'katsuura', 'ontario', 'bethel', 'nemuro', 'iola', 'happy valley-goose bay', 'srednebelaya', 'solnechnyy', 'ulaangom', 'tralee', 'keflavik', 'boguchany', 'ocher', 'anadyr', 'kapuskasing', 'uliastay', 'tulun', 'thunder bay', 'khovd', 'wisbech', 'mysen', 'horta', 'berezovyy', 'lianhe', 'dubovka', 'tsetserleg', 'sitka', 'milford haven', 'kovacica', 'klyuchi', 'tyumen', 'altay', 'la sarre', 'flin flon', 'motygino', 'ola', 'salekhard', 'whitehorse', 'thompson', 'aasiaat', "priob'ye", 'tura', 'suntar', 'college', 'pangody', 'oppdal', 'amga', 'vorgashor', 'bilibino', 'igarka', 'udachny', 'iqaluit', 'olonkinbyen', 'strezhevoy', 'tiksi', 'yellowknife', 'ust-nera', 'ilulissat', 'beloyarskiy', 'isafjordur', 'labytnangi', 'hammerfest', 'muravlenko', 'severo-yeniseyskiy', 'longyearbyen', 'polyarnyy', 'gadzhiyevo', 'dudinka', 'talnakh', 'nadym', "nar'yan-mar", 'badger', 'christchurch', 'portland', 'san julian', 'el calafate', 'ulladulla', 'richards bay', 'new plymouth', 'port pirie', 'saldanha', 'motueka', 'nuriootpa', 'general acha', 'porto seguro', 'la foa', 'esikhaleni', 'pisco', 'cable beach', 'alofi', 'mount isa', 'atherton', 'broome', 'luganville', 'karratha', 'charters towers', 'andovoranto', 'ponta pora', 'tocopilla', 'el charco', 'uturoa', 'daru', 'merizo village', 'kataragama', 'atafu village', 'yangambi', 'ahau', 'muriti', 'tangalle', 'kuala tungkal', 'macenta', 'menongue', 'hithadhoo', 'abak', 'maitum', 'kavieng', 'catio', 'lasem', 'cargados carajos', 'lagunillas', 'barranca', 'melgar',  ...

# %%
#print("test url")
#print(f"weather_api_key: {weather_api_key}")
#url = "http://api.openweathermap.org/data/2.5/weather?"
#units = "metric"
##base_url = f"{url}appid={api_key}&units={units}&q="
#test_url = f"{url}appid={weather_api_key}&{units}&q=" + "Paris"
#print(f"this works: http://api.openweathermap.org/data/2.5/weather?appid=99d9c9c3906f8432242946870f7f1b5c&units=metric&q=Paris")
#print(f"test_url: {test_url}")
#print(requests.get(test_url))
#city_weather = requests.get(test_url).json()
#city_lat = city_weather['coord']['lat']
#city_lng = city_weather['coord']['lon']
#city_max_temp = city_weather['main']['temp_max']
#city_humidity = city_weather['main']['humidity']
#city_clouds = city_weather['clouds']['all']
#city_wind = city_weather['wind']['speed']
#city_country = city_weather['sys']['country']
#city_date = city_weather['dt']
#
#print(f"city_lat: {city_lat}")
#print(f"city_lng: {city_lng}")
#print(f"city_max_temp: {city_max_temp}")
#print(f"city_humidity: {city_humidity}")
#print(f"city_clouds: {city_clouds}")
#print(f"city_wind: {city_wind}")
#print(f"city_country: {city_country}")
#print(f"city_date: {city_date}")

# %%
## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude

### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
print(weather_api_key)
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&{units}&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        print(f"city_lat: {city_lat}")
        print(f"city_lng: {city_lng}")
        print(f"city_max_temp: {city_max_temp}")
        print(f"city_humidity: {city_humidity}")
        print(f"city_clouds: {city_clouds}")
        print(f"city_wind: {city_wind}")
        print(f"city_country: {city_country}")
        print(f"city_date: {city_date}")
        

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# 99d9c9c3906f8432242946870f7f1b5c
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | edinburgh of the seven seas
# city_lat: -37.0676
# city_lng: -12.3116
# city_max_temp: 286.01
# city_humidity: 76
# city_clouds: 38
# city_wind: 12.84
# city_country: SH
# city_date: 1728598298
# Processing Record 2 of Set 1 | port-aux-francais
# city_lat: -49.35
# city_lng: 70.2167
# city_max_temp: 274.83
# city_humidity: 94
# city_clouds: 83
# city_wind: 17.55
# city_country: TF
# city_date: 1728598026
# Processing Record 3 of Set 1 | ushuaia
# city_lat: -54.8
# city_lng: -68.3
# city_max_temp: 278.17
# city_humidity: 84
# city_clouds: 99
# city_wind: 1.33
# city_country: AR
# city_date: 1728598150
# Processing Record 4 of Set 1 | bredasdorp
# city_lat: -34.5322
# city_lng: 20.0403
# city_max_temp: 285.71
# city_humidity: 82
# city_clouds: 100
# city_wind: 2.1
# city_country: ZA
# city_date: 1728598301
# Processing Record 5 of Set 1 | adamstown
# city_lat: -25.066
# city_lng: -130.1015
# city_max_temp: 294.28
# city_humidity: 86
# city_clouds: 100
# city_wind: 7.72
# city_country: PN
# city_date: 1728598302
# Processing Record 6 of Set 1 | puerto natales
# city_lat: -51.7236
# city_lng: -72.4875
# city_max_temp: 280.4
# city_humidity: 61
# city_clouds: 75
# city_wind: 8.75
# city_country: CL
# city_date: 1728598303
# Processing Record 7 of Set 1 | port elizabeth
# city_lat: -33.918
# city_lng: 25.5701
# city_max_temp: 288.88
# city_humidity: 93
# city_clouds: 89
# city_wind: 1.79
# city_country: ZA
# city_date: 1728598304
# Processing Record 8 of Set 1 | waitangi
# city_lat: -43.9535
# city_lng: -176.5597
# city_max_temp: 284.16
# city_humidity: 71
# city_clouds: 78
# city_wind: 1.79
# city_country: NZ
# city_date: 1728598305
# Processing Record 9 of Set 1 | grytviken
# city_lat: -54.2811
# city_lng: -36.5092
# city_max_temp: 272.09
# city_humidity: 95
# city_clouds: 100
# city_wind: 2.33
# city_country: GS
# city_date: 1728598306
# Processing Record 10 of Set 1 | blackmans bay
# city_lat: -43.0167
# city_lng: 147.3167
# city_max_temp: 285.78
# city_humidity: 59
# city_clouds: 85
# city_wind: 2.68
# city_country: AU
# city_date: 1728598308
# Processing Record 11 of Set 1 | punta arenas
# city_lat: -53.15
# city_lng: -70.9167
# city_max_temp: 280.21
# city_humidity: 65
# city_clouds: 75
# city_wind: 7.2
# city_country: CL
# city_date: 1728598309
# Processing Record 12 of Set 1 | hermanus
# city_lat: -34.4187
# city_lng: 19.2345
# city_max_temp: 287.81
# city_humidity: 78
# city_clouds: 99
# city_wind: 2.47
# city_country: ZA
# city_date: 1728598310
# Processing Record 13 of Set 1 | albany
# city_lat: 42.6001
# city_lng: -73.9662
# city_max_temp: 283.47
# city_humidity: 64
# city_clouds: 12
# city_wind: 1.34
# city_country: US
# city_date: 1728598123
# Processing Record 14 of Set 1 | port alfred
# city_lat: -33.5906
# city_lng: 26.891
# city_max_temp: 288.81
# city_humidity: 89
# city_clouds: 100
# city_wind: 0.89
# city_country: ZA
# city_date: 1728598312
# Processing Record 15 of Set 1 | papatowai
# city_lat: -46.5619
# city_lng: 169.4708
# city_max_temp: 287.51
# city_humidity: 45
# city_clouds: 38
# city_wind: 5.86
# city_country: NZ
# city_date: 1728598313
# Processing Record 16 of Set 1 | invercargill
# city_lat: -46.4
# city_lng: 168.35
# city_max_temp: 287.05
# city_humidity: 62
# city_clouds: 55
# city_wind: 4.92
# city_country: NZ
# city_date: 1728598314
# Processing Record 17 of Set 1 | margaret river
# city_lat: -33.95
# city_lng: 115.0667
# city_max_temp: 287.4
# city_humidity: 65
# city_clouds: 34
# city_wind: 4.59
# city_country: AU
# city_date: 1728598315
# Processing Record 18 of Set 1 | east london
# city_lat: -33.0153
# city_lng: 27.9116
# city_max_temp: 291.89
# city_humidity: 81
# city_clouds: 98
# city_wind: 8.21
# city_country: ZA
# city_date: 1728598317
# Processing Record 19 of Set 1 | constantia
# city_lat: 44.1833
# city_lng: 28.65
# city_max_temp: 289.65
# city_humidity: 63
# city_clouds: 72
# city_wind: 2.02
# city_country: RO
# city_date: 1728598318
# Processing Record 20 of Set 1 | chonchi
# city_lat: -42.6128
# city_lng: -73.8092
# city_max_temp: 284.88
# city_humidity: 72
# city_clouds: 95
# city_wind: 1.43
# city_country: CL
# city_date: 1728598319
# Processing Record 21 of Set 1 | quellon
# city_lat: -43.1167
# city_lng: -73.6167
# city_max_temp: 282.83
# city_humidity: 72
# city_clouds: 90
# city_wind: 1.35
# city_country: CL
# city_date: 1728598320
# Processing Record 22 of Set 1 | stanley
# city_lat: 54.868
# city_lng: -1.6985
# city_max_temp: 275.16
# city_humidity: 88
# city_clouds: 0
# city_wind: 2.06
# city_country: GB
# city_date: 1728598098
# Processing Record 23 of Set 1 | sarmiento
# city_lat: -45.5882
# city_lng: -69.07
# city_max_temp: 286.69
# city_humidity: 27
# city_clouds: 76
# city_wind: 11.55
# city_country: AR
# city_date: 1728598322
# Processing Record 24 of Set 1 | rio grande
# city_lat: -32.035
# city_lng: -52.0986
# city_max_temp: 290.21
# city_humidity: 92
# city_clouds: 100
# city_wind: 10.16
# city_country: BR
# city_date: 1728598323
# Processing Record 25 of Set 1 | plettenberg bay
# city_lat: -34.0527
# city_lng: 23.3716
# city_max_temp: 287.32
# city_humidity: 82
# city_clouds: 100
# city_wind: 3.1
# city_country: ZA
# city_date: 1728598044
# Processing Record 26 of Set 1 | lebu
# city_lat: -37.6167
# city_lng: -73.65
# city_max_temp: 285.54
# city_humidity: 92
# city_clouds: 41
# city_wind: 3.41
# city_country: CL
# city_date: 1728598325
# Processing Record 27 of Set 1 | port macquarie
# city_lat: -31.4333
# city_lng: 152.9167
# city_max_temp: 292.08
# city_humidity: 75
# city_clouds: 3
# city_wind: 1.13
# city_country: AU
# city_date: 1728598326
# Processing Record 28 of Set 1 | sale
# city_lat: 34.0389
# city_lng: -6.8166
# city_max_temp: 292.53
# city_humidity: 94
# city_clouds: 10
# city_wind: 0
# city_country: MA
# city_date: 1728598328
# Processing Record 29 of Set 1 | afaahiti
# city_lat: -17.75
# city_lng: -149.2833
# city_max_temp: 294.57
# city_humidity: 95
# city_clouds: 100
# city_wind: 6
# city_country: PF
# city_date: 1728598329
# Processing Record 30 of Set 1 | healesville
# city_lat: -37.65
# city_lng: 145.5167
# city_max_temp: 283.4
# city_humidity: 89
# city_clouds: 31
# city_wind: 1.29
# city_country: AU
# city_date: 1728598330
# Processing Record 31 of Set 1 | constitucion
# city_lat: -35.3333
# city_lng: -72.4167
# city_max_temp: 286.68
# city_humidity: 75
# city_clouds: 81
# city_wind: 4.14
# city_country: CL
# city_date: 1728598256
# Processing Record 32 of Set 1 | el trebol
# city_lat: -32.2008
# city_lng: -61.7014
# city_max_temp: 294.31
# city_humidity: 39
# city_clouds: 100
# city_wind: 1.4
# city_country: AR
# city_date: 1728598332
# Processing Record 33 of Set 1 | kingston
# city_lat: 17.997
# city_lng: -76.7936
# city_max_temp: 303.8
# city_humidity: 77
# city_clouds: 95
# city_wind: 1.53
# city_country: JM
# city_date: 1728598319
# Processing Record 34 of Set 1 | santa elena
# city_lat: -2.2333
# city_lng: -80.85
# city_max_temp: 295.9
# city_humidity: 83
# city_clouds: 75
# city_wind: 5.66
# city_country: EC
# city_date: 1728598334
# Processing Record 35 of Set 1 | mar del plata
# city_lat: -38.0023
# city_lng: -57.5575
# city_max_temp: 289
# city_humidity: 89
# city_clouds: 43
# city_wind: 8.05
# city_country: AR
# city_date: 1728598258
# Processing Record 36 of Set 1 | pozo del molle
# city_lat: -32.0186
# city_lng: -62.9198
# city_max_temp: 293.33
# city_humidity: 49
# city_clouds: 98
# city_wind: 2.28
# city_country: AR
# city_date: 1728598274
# Processing Record 37 of Set 1 | ancud
# city_lat: -41.8697
# city_lng: -73.8203
# city_max_temp: 281.72
# city_humidity: 87
# city_clouds: 100
# city_wind: 2.66
# city_country: CL
# city_date: 1728598338
# Processing Record 38 of Set 1 | wynyard
# city_lat: -41
# city_lng: 145.7167
# city_max_temp: 285.05
# city_humidity: 88
# city_clouds: 57
# city_wind: 1.34
# city_country: AU
# city_date: 1728598339
# Processing Record 39 of Set 1 | avarua
# city_lat: -21.2078
# city_lng: -159.775
# city_max_temp: 298.18
# city_humidity: 69
# city_clouds: 40
# city_wind: 7.2
# city_country: CK
# city_date: 1728598340
# Processing Record 40 of Set 1 | thames
# city_lat: -37.1333
# city_lng: 175.5333
# city_max_temp: 284.1
# city_humidity: 90
# city_clouds: 98
# city_wind: 2.06
# city_country: NZ
# city_date: 1728598341
# Processing Record 41 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 42 of Set 1 | port saint john's
# city_lat: -31.6229
# city_lng: 29.5448
# city_max_temp: 294.08
# city_humidity: 83
# city_clouds: 70
# city_wind: 7.77
# city_country: ZA
# city_date: 1728598343
# Processing Record 43 of Set 1 | newnham
# city_lat: -41.3833
# city_lng: 147.1333
# city_max_temp: 284.68
# city_humidity: 66
# city_clouds: 20
# city_wind: 6.69
# city_country: AU
# city_date: 1728598344
# Processing Record 44 of Set 1 | tsiombe
# city_lat: -25.3
# city_lng: 45.4833
# city_max_temp: 295.07
# city_humidity: 74
# city_clouds: 4
# city_wind: 3.61
# city_country: MG
# city_date: 1728598345
# Processing Record 45 of Set 1 | tolanaro
# city_lat: -25.0319
# city_lng: 46.9987
# city_max_temp: 294.19
# city_humidity: 80
# city_clouds: 0
# city_wind: 6.23
# city_country: MG
# city_date: 1728598347
# Processing Record 46 of Set 1 | arraial do cabo
# city_lat: -22.9661
# city_lng: -42.0278
# city_max_temp: 294.39
# city_humidity: 91
# city_clouds: 100
# city_wind: 10.54
# city_country: BR
# city_date: 1728598348
# Processing Record 47 of Set 1 | laguna
# city_lat: 38.421
# city_lng: -121.4238
# city_max_temp: 302.72
# city_humidity: 43
# city_clouds: 0
# city_wind: 2.57
# city_country: US
# city_date: 1728598349
# Processing Record 48 of Set 1 | yeppoon
# city_lat: -23.1333
# city_lng: 150.7333
# city_max_temp: 294.54
# city_humidity: 80
# city_clouds: 82
# city_wind: 7.2
# city_country: AU
# city_date: 1728598350
# Processing Record 49 of Set 1 | luderitz
# city_lat: -26.6481
# city_lng: 15.1594
# city_max_temp: 288.35
# city_humidity: 71
# city_clouds: 0
# city_wind: 4.51
# city_country: NA
# city_date: 1728598351
# Processing Record 50 of Set 1 | west island
# city_lat: -12.1568
# city_lng: 96.8225
# city_max_temp: 299.14
# city_humidity: 83
# city_clouds: 75
# city_wind: 7.2
# city_country: CC
# city_date: 1728598352
# Processing Record 0 of Set 2 | taltal
# city_lat: -25.4
# city_lng: -70.4833
# city_max_temp: 289.77
# city_humidity: 75
# city_clouds: 0
# city_wind: 2.73
# city_country: CL
# city_date: 1728598220
# Processing Record 1 of Set 2 | lubango
# city_lat: -14.9172
# city_lng: 13.4925
# city_max_temp: 291.92
# city_humidity: 47
# city_clouds: 64
# city_wind: 0.9
# city_country: AO
# city_date: 1728598354
# Processing Record 2 of Set 2 | shakawe
# city_lat: -18.3667
# city_lng: 21.85
# city_max_temp: 293.42
# city_humidity: 21
# city_clouds: 0
# city_wind: 2.39
# city_country: BW
# city_date: 1728598355
# Processing Record 3 of Set 2 | goianesia
# city_lat: -15.3175
# city_lng: -49.1175
# city_max_temp: 301.44
# city_humidity: 46
# city_clouds: 100
# city_wind: 2.53
# city_country: BR
# city_date: 1728598070
# Processing Record 4 of Set 2 | belmonte
# city_lat: -15.8631
# city_lng: -38.8828
# city_max_temp: 297.2
# city_humidity: 83
# city_clouds: 48
# city_wind: 3.32
# city_country: BR
# city_date: 1728598358
# Processing Record 5 of Set 2 | alice springs
# city_lat: -23.7
# city_lng: 133.8833
# city_max_temp: 289.9
# city_humidity: 31
# city_clouds: 21
# city_wind: 0.51
# city_country: AU
# city_date: 1728598359
# Processing Record 6 of Set 2 | moranbah
# city_lat: -22.0016
# city_lng: 148.0466
# city_max_temp: 294.74
# city_humidity: 68
# city_clouds: 90
# city_wind: 5.75
# city_country: AU
# city_date: 1728598360
# Processing Record 7 of Set 2 | carnarvon
# city_lat: -24.8667
# city_lng: 113.6333
# city_max_temp: 295.52
# city_humidity: 63
# city_clouds: 0
# city_wind: 2.33
# city_country: AU
# city_date: 1728598361
# Processing Record 8 of Set 2 | prado
# city_lat: -17.3411
# city_lng: -39.2208
# city_max_temp: 298.3
# city_humidity: 80
# city_clouds: 100
# city_wind: 3.96
# city_country: BR
# city_date: 1728598362
# Processing Record 9 of Set 2 | ondjiva
# city_lat: -17.0667
# city_lng: 15.7333
# city_max_temp: 296.1
# city_humidity: 15
# city_clouds: 30
# city_wind: 3.23
# city_country: AO
# city_date: 1728598363
# Processing Record 10 of Set 2 | saint-paul
# city_lat: -21.0096
# city_lng: 55.2707
# city_max_temp: 295.2
# city_humidity: 91
# city_clouds: 96
# city_wind: 2.05
# city_country: RE
# city_date: 1728598364
# Processing Record 11 of Set 2 | ambodifotatra
# city_lat: -16.9833
# city_lng: 49.85
# city_max_temp: 297.02
# city_humidity: 72
# city_clouds: 27
# city_wind: 6.48
# city_country: MG
# city_date: 1728598366
# Processing Record 12 of Set 2 | cairns city
# City not found. Skipping...
# Processing Record 13 of Set 2 | saint-philippe
# city_lat: -21.3585
# city_lng: 55.7679
# city_max_temp: 294.48
# city_humidity: 83
# city_clouds: 50
# city_wind: 6.5
# city_country: RE
# city_date: 1728598368
# Processing Record 14 of Set 2 | broken hill
# city_lat: -31.95
# city_lng: 141.4333
# city_max_temp: 285.9
# city_humidity: 48
# city_clouds: 64
# city_wind: 9.3
# city_country: AU
# city_date: 1728598369
# Processing Record 15 of Set 2 | port mathurin
# city_lat: -19.6833
# city_lng: 63.4167
# city_max_temp: 295.63
# city_humidity: 83
# city_clouds: 98
# city_wind: 9.67
# city_country: MU
# city_date: 1728598370
# Processing Record 16 of Set 2 | coquimbo
# city_lat: -29.9533
# city_lng: -71.3436
# city_max_temp: 288.7
# city_humidity: 73
# city_clouds: 40
# city_wind: 3.6
# city_country: CL
# city_date: 1728598251
# Processing Record 17 of Set 2 | tamarin
# city_lat: -20.3256
# city_lng: 57.3706
# city_max_temp: 295.22
# city_humidity: 74
# city_clouds: 68
# city_wind: 6.77
# city_country: MU
# city_date: 1728598285
# Processing Record 18 of Set 2 | emerald
# city_lat: -23.5333
# city_lng: 148.1667
# city_max_temp: 294.45
# city_humidity: 76
# city_clouds: 2
# city_wind: 3.79
# city_country: AU
# city_date: 1728598373
# Processing Record 19 of Set 2 | callao
# city_lat: -12.0667
# city_lng: -77.15
# city_max_temp: 290.31
# city_humidity: 82
# city_clouds: 100
# city_wind: 2.57
# city_country: PE
# city_date: 1728598375
# Processing Record 20 of Set 2 | kununurra
# city_lat: -15.7667
# city_lng: 128.7333
# city_max_temp: 297.14
# city_humidity: 88
# city_clouds: 4
# city_wind: 1.54
# city_country: AU
# city_date: 1728598376
# Processing Record 21 of Set 2 | flying fish cove
# city_lat: -10.4217
# city_lng: 105.6791
# city_max_temp: 298.97
# city_humidity: 88
# city_clouds: 75
# city_wind: 5.14
# city_country: CX
# city_date: 1728598249
# Processing Record 22 of Set 2 | swakopmund
# city_lat: -22.6833
# city_lng: 14.5333
# city_max_temp: 288.14
# city_humidity: 79
# city_clouds: 0
# city_wind: 0.89
# city_country: NA
# city_date: 1728598378
# Processing Record 23 of Set 2 | puerto ayora
# city_lat: -0.7393
# city_lng: -90.3518
# city_max_temp: 294.01
# city_humidity: 92
# city_clouds: 84
# city_wind: 3.13
# city_country: EC
# city_date: 1728598379
# Processing Record 24 of Set 2 | inirida
# city_lat: 3.8653
# city_lng: -67.9239
# city_max_temp: 301.87
# city_humidity: 67
# city_clouds: 100
# city_wind: 0.88
# city_country: CO
# city_date: 1728598380
# Processing Record 25 of Set 2 | moroto
# city_lat: 2.5345
# city_lng: 34.6666
# city_max_temp: 296.03
# city_humidity: 51
# city_clouds: 78
# city_wind: 1.04
# city_country: UG
# city_date: 1728598381
# Processing Record 26 of Set 2 | antsiranana
# city_lat: -12.2787
# city_lng: 49.2917
# city_max_temp: 297.42
# city_humidity: 67
# city_clouds: 1
# city_wind: 8.86
# city_country: MG
# city_date: 1728598382
# Processing Record 27 of Set 2 | mejit
# city_lat: 10.2753
# city_lng: 170.8646
# city_max_temp: 301.32
# city_humidity: 76
# city_clouds: 82
# city_wind: 5.51
# city_country: MH
# city_date: 1728598384
# Processing Record 28 of Set 2 | pamandzi
# city_lat: -12.7967
# city_lng: 45.2794
# city_max_temp: 298.03
# city_humidity: 88
# city_clouds: 0
# city_wind: 1.54
# city_country: YT
# city_date: 1728598385
# Processing Record 29 of Set 2 | huanuco
# city_lat: -9.9329
# city_lng: -76.2415
# city_max_temp: 294.4
# city_humidity: 70
# city_clouds: 91
# city_wind: 3.28
# city_country: PE
# city_date: 1728598386
# Processing Record 30 of Set 2 | nabire
# city_lat: -3.3667
# city_lng: 135.4833
# city_max_temp: 297.86
# city_humidity: 90
# city_clouds: 100
# city_wind: 1.35
# city_country: ID
# city_date: 1728598387
# Processing Record 31 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 32 of Set 2 | georgetown
# city_lat: 5.4112
# city_lng: 100.3354
# city_max_temp: 300.11
# city_humidity: 83
# city_clouds: 20
# city_wind: 1.03
# city_country: MY
# city_date: 1728598389
# Processing Record 33 of Set 2 | sao raimundo nonato
# city_lat: -9.0153
# city_lng: -42.6994
# city_max_temp: 305.5
# city_humidity: 25
# city_clouds: 9
# city_wind: 1.08
# city_country: BR
# city_date: 1728598390
# Processing Record 34 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 35 of Set 2 | ugoofaaru
# city_lat: 5.6667
# city_lng: 73
# city_max_temp: 300.18
# city_humidity: 82
# city_clouds: 100
# city_wind: 10.1
# city_country: MV
# city_date: 1728598393
# Processing Record 36 of Set 2 | yaren
# city_lat: -0.5472
# city_lng: 166.916
# city_max_temp: 301.31
# city_humidity: 67
# city_clouds: 100
# city_wind: 5.3
# city_country: NR
# city_date: 1728598394
# Processing Record 37 of Set 2 | olinda
# city_lat: -8.0089
# city_lng: -34.8553
# city_max_temp: 300
# city_humidity: 74
# city_clouds: 40
# city_wind: 4.12
# city_country: BR
# city_date: 1728598395
# Processing Record 38 of Set 2 | fale old settlement
# city_lat: -9.3852
# city_lng: -171.2468
# city_max_temp: 300.95
# city_humidity: 78
# city_clouds: 29
# city_wind: 4.65
# city_country: TK
# city_date: 1728598396
# Processing Record 39 of Set 2 | hell-ville
# city_lat: -13.4
# city_lng: 48.2667
# city_max_temp: 299.69
# city_humidity: 68
# city_clouds: 8
# city_wind: 2.65
# city_country: MG
# city_date: 1728598397
# Processing Record 40 of Set 2 | jamestown
# city_lat: 42.097
# city_lng: -79.2353
# city_max_temp: 282.95
# city_humidity: 66
# city_clouds: 0
# city_wind: 3.09
# city_country: US
# city_date: 1728598398
# Processing Record 41 of Set 2 | buala
# city_lat: -8.145
# city_lng: 159.5921
# city_max_temp: 301.36
# city_humidity: 76
# city_clouds: 65
# city_wind: 2.51
# city_country: SB
# city_date: 1728598399
# Processing Record 42 of Set 2 | sinabang
# city_lat: 2.4803
# city_lng: 96.3801
# city_max_temp: 297.54
# city_humidity: 95
# city_clouds: 100
# city_wind: 2.55
# city_country: ID
# city_date: 1728598400
# Processing Record 43 of Set 2 | palikir - national government center
# city_lat: 6.9248
# city_lng: 158.1611
# city_max_temp: 303.56
# city_humidity: 74
# city_clouds: 100
# city_wind: 4.12
# city_country: FM
# city_date: 1728598401
# Processing Record 44 of Set 2 | mili
# city_lat: 6.0815
# city_lng: 171.735
# city_max_temp: 301.98
# city_humidity: 72
# city_clouds: 32
# city_wind: 4.75
# city_country: MH
# city_date: 1728598403
# Processing Record 45 of Set 2 | ibimirim
# city_lat: -8.5406
# city_lng: -37.6903
# city_max_temp: 303.59
# city_humidity: 34
# city_clouds: 66
# city_wind: 8.34
# city_country: BR
# city_date: 1728598404
# Processing Record 46 of Set 2 | malango
# city_lat: -2.9627
# city_lng: 119.9001
# city_max_temp: 291.86
# city_humidity: 99
# city_clouds: 100
# city_wind: 1.07
# city_country: ID
# city_date: 1728598405
# Processing Record 47 of Set 2 | hayma'
# City not found. Skipping...
# Processing Record 48 of Set 2 | mabaruma
# city_lat: 8.2
# city_lng: -59.7833
# city_max_temp: 300.15
# city_humidity: 78
# city_clouds: 99
# city_wind: 2.46
# city_country: GY
# city_date: 1728598407
# Processing Record 49 of Set 2 | gaalkacyo
# city_lat: 6.7697
# city_lng: 47.4308
# city_max_temp: 298.84
# city_humidity: 68
# city_clouds: 17
# city_wind: 7.22
# city_country: SO
# city_date: 1728598408
# Processing Record 0 of Set 3 | kirakira
# city_lat: -10.4544
# city_lng: 161.9205
# city_max_temp: 301.61
# city_humidity: 76
# city_clouds: 43
# city_wind: 3.79
# city_country: SB
# city_date: 1728598409
# Processing Record 1 of Set 3 | bamboo flat
# city_lat: 11.7
# city_lng: 92.7167
# city_max_temp: 299.56
# city_humidity: 76
# city_clouds: 35
# city_wind: 0.68
# city_country: IN
# city_date: 1728598411
# Processing Record 2 of Set 3 | cabo san lucas
# city_lat: 22.8909
# city_lng: -109.9124
# city_max_temp: 304.32
# city_humidity: 66
# city_clouds: 20
# city_wind: 3.6
# city_country: MX
# city_date: 1728598397
# Processing Record 3 of Set 3 | flores costa cuca
# city_lat: 14.65
# city_lng: -91.8167
# city_max_temp: 298.22
# city_humidity: 62
# city_clouds: 69
# city_wind: 1.38
# city_country: GT
# city_date: 1728598413
# Processing Record 4 of Set 3 | rongelap
# city_lat: 11.1635
# city_lng: 166.8941
# city_max_temp: 300.04
# city_humidity: 83
# city_clouds: 100
# city_wind: 5.86
# city_country: MH
# city_date: 1728598414
# Processing Record 5 of Set 3 | san patricio
# city_lat: 28.017
# city_lng: -97.5169
# city_max_temp: 305.12
# city_humidity: 31
# city_clouds: 0
# city_wind: 3.74
# city_country: US
# city_date: 1728598415
# Processing Record 6 of Set 3 | mukah
# City not found. Skipping...
# Processing Record 7 of Set 3 | acarau
# city_lat: -2.8856
# city_lng: -40.12
# city_max_temp: 299.05
# city_humidity: 79
# city_clouds: 28
# city_wind: 8.15
# city_country: BR
# city_date: 1728598417
# Processing Record 8 of Set 3 | puerto armuelles
# city_lat: 8.2833
# city_lng: -82.8667
# city_max_temp: 298.76
# city_humidity: 87
# city_clouds: 97
# city_wind: 3.13
# city_country: PA
# city_date: 1728598418
# Processing Record 9 of Set 3 | tabou
# city_lat: 4.423
# city_lng: -7.3528
# city_max_temp: 297.82
# city_humidity: 90
# city_clouds: 87
# city_wind: 3.61
# city_country: CI
# city_date: 1728598420
# Processing Record 10 of Set 3 | caleta de carquin
# city_lat: -11.0925
# city_lng: -77.6267
# city_max_temp: 292.03
# city_humidity: 82
# city_clouds: 41
# city_wind: 4.8
# city_country: PE
# city_date: 1728598421
# Processing Record 11 of Set 3 | bima
# city_lat: -8.4667
# city_lng: 118.7167
# city_max_temp: 297.71
# city_humidity: 94
# city_clouds: 50
# city_wind: 1.36
# city_country: ID
# city_date: 1728598422
# Processing Record 12 of Set 3 | yanam
# city_lat: 16.7333
# city_lng: 82.2167
# city_max_temp: 297.61
# city_humidity: 96
# city_clouds: 100
# city_wind: 1.23
# city_country: IN
# city_date: 1728598423
# Processing Record 13 of Set 3 | bubaque
# city_lat: 11.2833
# city_lng: -15.8333
# city_max_temp: 300.25
# city_humidity: 75
# city_clouds: 100
# city_wind: 5.32
# city_country: GW
# city_date: 1728598424
# Processing Record 14 of Set 3 | tanjung selor
# city_lat: 2.8372
# city_lng: 117.3642
# city_max_temp: 296.36
# city_humidity: 98
# city_clouds: 45
# city_wind: 0.57
# city_country: ID
# city_date: 1728598425
# Processing Record 15 of Set 3 | tual
# city_lat: -5.6667
# city_lng: 132.75
# city_max_temp: 300.71
# city_humidity: 84
# city_clouds: 100
# city_wind: 7.79
# city_country: ID
# city_date: 1728598426
# Processing Record 16 of Set 3 | tekkali
# city_lat: 18.6167
# city_lng: 84.2333
# city_max_temp: 297.46
# city_humidity: 92
# city_clouds: 87
# city_wind: 1.61
# city_country: IN
# city_date: 1728598427
# Processing Record 17 of Set 3 | jiaojiang
# city_lat: 28.6803
# city_lng: 121.4428
# city_max_temp: 286.68
# city_humidity: 85
# city_clouds: 36
# city_wind: 1.95
# city_country: CN
# city_date: 1728598429
# Processing Record 18 of Set 3 | wailua homesteads
# city_lat: 22.0669
# city_lng: -159.378
# city_max_temp: 301.59
# city_humidity: 75
# city_clouds: 75
# city_wind: 6.69
# city_country: US
# city_date: 1728598430
# Processing Record 19 of Set 3 | ribeira grande
# city_lat: 38.5167
# city_lng: -28.7
# city_max_temp: 293.02
# city_humidity: 87
# city_clouds: 80
# city_wind: 3.58
# city_country: PT
# city_date: 1728598431
# Processing Record 20 of Set 3 | lihue
# city_lat: 21.9789
# city_lng: -159.3672
# city_max_temp: 301.92
# city_humidity: 65
# city_clouds: 75
# city_wind: 6.69
# city_country: US
# city_date: 1728598432
# Processing Record 21 of Set 3 | heroica guaymas
# city_lat: 27.9333
# city_lng: -110.9
# city_max_temp: 304.8
# city_humidity: 70
# city_clouds: 20
# city_wind: 8.23
# city_country: MX
# city_date: 1728598185
# Processing Record 22 of Set 3 | utrik
# city_lat: 11.2278
# city_lng: 169.8474
# city_max_temp: 301.46
# city_humidity: 77
# city_clouds: 77
# city_wind: 4.49
# city_country: MH
# city_date: 1728598434
# Processing Record 23 of Set 3 | enewetak
# city_lat: 11.3474
# city_lng: 162.3373
# city_max_temp: 301.9
# city_humidity: 75
# city_clouds: 99
# city_wind: 3.93
# city_country: MH
# city_date: 1728598435
# Processing Record 24 of Set 3 | zouerate
# city_lat: 22.7187
# city_lng: -12.4521
# city_max_temp: 306.41
# city_humidity: 25
# city_clouds: 25
# city_wind: 4.02
# city_country: MR
# city_date: 1728598199
# Processing Record 25 of Set 3 | vientiane
# city_lat: 17.9667
# city_lng: 102.6
# city_max_temp: 295.1
# city_humidity: 91
# city_clouds: 48
# city_wind: 0.61
# city_country: LA
# city_date: 1728598438
# Processing Record 26 of Set 3 | nishinoomote
# city_lat: 30.7333
# city_lng: 131
# city_max_temp: 297.26
# city_humidity: 69
# city_clouds: 73
# city_wind: 4.96
# city_country: JP
# city_date: 1728598439
# Processing Record 27 of Set 3 | lompoc
# city_lat: 34.6391
# city_lng: -120.4579
# city_max_temp: 296.22
# city_humidity: 70
# city_clouds: 0
# city_wind: 5.66
# city_country: US
# city_date: 1728598440
# Processing Record 28 of Set 3 | hawaiian paradise park
# city_lat: 19.5933
# city_lng: -154.9731
# city_max_temp: 300.88
# city_humidity: 77
# city_clouds: 75
# city_wind: 4.12
# city_country: US
# city_date: 1728598441
# Processing Record 29 of Set 3 | jaltenango de la paz
# city_lat: 15.9167
# city_lng: -92.7167
# city_max_temp: 297.78
# city_humidity: 78
# city_clouds: 100
# city_wind: 0.85
# city_country: MX
# city_date: 1728598425
# Processing Record 30 of Set 3 | huanggang
# city_lat: 23.677
# city_lng: 116.9996
# city_max_temp: 295.54
# city_humidity: 80
# city_clouds: 100
# city_wind: 2.41
# city_country: CN
# city_date: 1728598443
# Processing Record 31 of Set 3 | lashio
# city_lat: 22.9333
# city_lng: 97.75
# city_max_temp: 290.88
# city_humidity: 99
# city_clouds: 30
# city_wind: 0.42
# city_country: MM
# city_date: 1728598159
# Processing Record 32 of Set 3 | awjilah
# city_lat: 29.1081
# city_lng: 21.2869
# city_max_temp: 302.26
# city_humidity: 23
# city_clouds: 3
# city_wind: 4.08
# city_country: LY
# city_date: 1728598445
# Processing Record 33 of Set 3 | port lavaca
# city_lat: 28.615
# city_lng: -96.6261
# city_max_temp: 305.96
# city_humidity: 36
# city_clouds: 0
# city_wind: 3.95
# city_country: US
# city_date: 1728598446
# Processing Record 34 of Set 3 | ubari
# city_lat: 26.5921
# city_lng: 12.7805
# city_max_temp: 304.36
# city_humidity: 18
# city_clouds: 3
# city_wind: 4.22
# city_country: LY
# city_date: 1728598448
# Processing Record 35 of Set 3 | pathein
# city_lat: 16.7833
# city_lng: 94.7333
# city_max_temp: 297.68
# city_humidity: 89
# city_clouds: 16
# city_wind: 1.78
# city_country: MM
# city_date: 1728598449
# Processing Record 36 of Set 3 | pedro escobedo
# city_lat: 20.5
# city_lng: -100.1333
# city_max_temp: 297.16
# city_humidity: 17
# city_clouds: 40
# city_wind: 8.23
# city_country: MX
# city_date: 1728598450
# Processing Record 37 of Set 3 | ad dilam
# city_lat: 23.9915
# city_lng: 47.1627
# city_max_temp: 300.64
# city_humidity: 20
# city_clouds: 0
# city_wind: 3.87
# city_country: SA
# city_date: 1728598451
# Processing Record 38 of Set 3 | chhindwara
# city_lat: 22.0667
# city_lng: 78.9333
# city_max_temp: 294.74
# city_humidity: 86
# city_clouds: 72
# city_wind: 1.58
# city_country: IN
# city_date: 1728598452
# Processing Record 39 of Set 3 | mukalla
# city_lat: 14.5425
# city_lng: 49.1242
# city_max_temp: 298.18
# city_humidity: 83
# city_clouds: 1
# city_wind: 1.27
# city_country: YE
# city_date: 1728598453
# Processing Record 40 of Set 3 | tangping
# city_lat: 22.0265
# city_lng: 111.9323
# city_max_temp: 295.45
# city_humidity: 74
# city_clouds: 41
# city_wind: 1.7
# city_country: CN
# city_date: 1728598454
# Processing Record 41 of Set 3 | pavuluru
# city_lat: 15.8529
# city_lng: 80.1647
# city_max_temp: 297.9
# city_humidity: 94
# city_clouds: 100
# city_wind: 2.14
# city_country: IN
# city_date: 1728598455
# Processing Record 42 of Set 3 | bardai
# city_lat: 11.65
# city_lng: 7.2333
# city_max_temp: 297.5
# city_humidity: 65
# city_clouds: 48
# city_wind: 2.35
# city_country: NG
# city_date: 1728598456
# Processing Record 43 of Set 3 | san pedro
# city_lat: 14.35
# city_lng: 121.0167
# city_max_temp: 299.72
# city_humidity: 94
# city_clouds: 20
# city_wind: 1.54
# city_country: PH
# city_date: 1728598458
# Processing Record 44 of Set 3 | as sulayyil
# city_lat: 20.4607
# city_lng: 45.5779
# city_max_temp: 299.6
# city_humidity: 22
# city_clouds: 13
# city_wind: 2.59
# city_country: SA
# city_date: 1728598459
# Processing Record 45 of Set 3 | pasuquin
# city_lat: 18.3328
# city_lng: 120.6177
# city_max_temp: 297.12
# city_humidity: 94
# city_clouds: 20
# city_wind: 1.54
# city_country: PH
# city_date: 1728598460
# Processing Record 46 of Set 3 | saipan
# city_lat: 15.1355
# city_lng: 145.701
# city_max_temp: 300.54
# city_humidity: 89
# city_clouds: 100
# city_wind: 2.57
# city_country: MP
# city_date: 1728598461
# Processing Record 47 of Set 3 | gopalpur
# city_lat: 19.2667
# city_lng: 84.9167
# city_max_temp: 298.79
# city_humidity: 88
# city_clouds: 84
# city_wind: 1.84
# city_country: IN
# city_date: 1728598462
# Processing Record 48 of Set 3 | hamilton
# city_lat: 39.1834
# city_lng: -84.5333
# city_max_temp: 294.17
# city_humidity: 40
# city_clouds: 0
# city_wind: 1.54
# city_country: US
# city_date: 1728598228
# Processing Record 49 of Set 3 | am djarass
# City not found. Skipping...
# Processing Record 0 of Set 4 | remire-montjoly
# city_lat: 4.9167
# city_lng: -52.2667
# city_max_temp: 301.17
# city_humidity: 83
# city_clouds: 0
# city_wind: 1.54
# city_country: GF
# city_date: 1728598465
# Processing Record 1 of Set 4 | kodiak
# city_lat: 57.79
# city_lng: -152.4072
# city_max_temp: 279.88
# city_humidity: 65
# city_clouds: 75
# city_wind: 2.57
# city_country: US
# city_date: 1728598401
# Processing Record 2 of Set 4 | yuzhno-kurilsk
# city_lat: 44.0306
# city_lng: 145.8556
# city_max_temp: 283.16
# city_humidity: 78
# city_clouds: 100
# city_wind: 7.65
# city_country: RU
# city_date: 1728598468
# Processing Record 3 of Set 4 | pratt
# city_lat: 37.6439
# city_lng: -98.7376
# city_max_temp: 302.27
# city_humidity: 32
# city_clouds: 0
# city_wind: 5.66
# city_country: US
# city_date: 1728598469
# Processing Record 4 of Set 4 | jinan
# city_lat: 36.6683
# city_lng: 116.9972
# city_max_temp: 288.08
# city_humidity: 37
# city_clouds: 0
# city_wind: 0.93
# city_country: CN
# city_date: 1728598470
# Processing Record 5 of Set 4 | mary
# city_lat: 37
# city_lng: 62.5
# city_max_temp: 295.32
# city_humidity: 23
# city_clouds: 0
# city_wind: 3.93
# city_country: TM
# city_date: 1728598471
# Processing Record 6 of Set 4 | loveland
# city_lat: 40.3978
# city_lng: -105.075
# city_max_temp: 303.82
# city_humidity: 17
# city_clouds: 0
# city_wind: 3.6
# city_country: US
# city_date: 1728598472
# Processing Record 7 of Set 4 | al azraq ash shamali
# City not found. Skipping...
# Processing Record 8 of Set 4 | haiku-pauwela
# city_lat: 20.9219
# city_lng: -156.3051
# city_max_temp: 302.16
# city_humidity: 75
# city_clouds: 83
# city_wind: 10.73
# city_country: US
# city_date: 1728598474
# Processing Record 9 of Set 4 | arrifes
# city_lat: 37.7667
# city_lng: -25.7
# city_max_temp: 292.29
# city_humidity: 77
# city_clouds: 40
# city_wind: 3.6
# city_country: PT
# city_date: 1728598476
# Processing Record 10 of Set 4 | conception bay south
# city_lat: 47.4999
# city_lng: -52.9981
# city_max_temp: 284.67
# city_humidity: 97
# city_clouds: 100
# city_wind: 0.63
# city_country: CA
# city_date: 1728598477
# Processing Record 11 of Set 4 | kincardine
# city_lat: 56.0667
# city_lng: -3.7167
# city_max_temp: 277.63
# city_humidity: 88
# city_clouds: 35
# city_wind: 3.13
# city_country: GB
# city_date: 1728598478
# Processing Record 12 of Set 4 | praia da vitoria
# city_lat: 38.7333
# city_lng: -27.0667
# city_max_temp: 293.29
# city_humidity: 77
# city_clouds: 40
# city_wind: 11.58
# city_country: PT
# city_date: 1728598479
# Processing Record 13 of Set 4 | kill devil hills
# city_lat: 36.0307
# city_lng: -75.676
# city_max_temp: 289.81
# city_humidity: 64
# city_clouds: 75
# city_wind: 6.17
# city_country: US
# city_date: 1728598480
# Processing Record 14 of Set 4 | petropavlovsk-kamchatsky
# city_lat: 53.0452
# city_lng: 158.6483
# city_max_temp: 271.48
# city_humidity: 64
# city_clouds: 0
# city_wind: 4
# city_country: RU
# city_date: 1728598440
# Processing Record 15 of Set 4 | susanville
# city_lat: 40.4163
# city_lng: -120.653
# city_max_temp: 300.27
# city_humidity: 18
# city_clouds: 100
# city_wind: 1.34
# city_country: US
# city_date: 1728598482
# Processing Record 16 of Set 4 | buarcos
# city_lat: 40.166
# city_lng: -8.8768
# city_max_temp: 289.36
# city_humidity: 78
# city_clouds: 39
# city_wind: 2.55
# city_country: PT
# city_date: 1728598483
# Processing Record 17 of Set 4 | brookings
# city_lat: 44.3114
# city_lng: -96.7984
# city_max_temp: 301.15
# city_humidity: 41
# city_clouds: 0
# city_wind: 4.63
# city_country: US
# city_date: 1728598484
# Processing Record 18 of Set 4 | boryeong
# city_lat: 36.3493
# city_lng: 126.5977
# city_max_temp: 289.61
# city_humidity: 78
# city_clouds: 0
# city_wind: 0.83
# city_country: KR
# city_date: 1728598486
# Processing Record 19 of Set 4 | shofirkon shahri
# City not found. Skipping...
# Processing Record 20 of Set 4 | montecatini-terme
# city_lat: 43.8835
# city_lng: 10.7736
# city_max_temp: 290.92
# city_humidity: 80
# city_clouds: 87
# city_wind: 3.13
# city_country: IT
# city_date: 1728598460
# Processing Record 21 of Set 4 | moab
# city_lat: 38.5733
# city_lng: -109.5498
# city_max_temp: 304.18
# city_humidity: 13
# city_clouds: 8
# city_wind: 2.36
# city_country: US
# city_date: 1728598489
# Processing Record 22 of Set 4 | eureka
# city_lat: 40.8021
# city_lng: -124.1637
# city_max_temp: 291.62
# city_humidity: 66
# city_clouds: 35
# city_wind: 2.09
# city_country: US
# city_date: 1728598466
# Processing Record 23 of Set 4 | fortuna
# city_lat: 40.5982
# city_lng: -124.1573
# city_max_temp: 293.11
# city_humidity: 70
# city_clouds: 0
# city_wind: 5.66
# city_country: US
# city_date: 1728598491
# Processing Record 24 of Set 4 | turkmenabat
# city_lat: 39.0733
# city_lng: 63.5786
# city_max_temp: 289.14
# city_humidity: 59
# city_clouds: 0
# city_wind: 2.06
# city_country: TM
# city_date: 1728598492
# Processing Record 25 of Set 4 | al kut
# city_lat: 32.5147
# city_lng: 45.819
# city_max_temp: 301.91
# city_humidity: 12
# city_clouds: 0
# city_wind: 1.53
# city_country: IQ
# city_date: 1728598493
# Processing Record 26 of Set 4 | ohara
# city_lat: 35.25
# city_lng: 140.3833
# city_max_temp: 291.19
# city_humidity: 79
# city_clouds: 77
# city_wind: 5.17
# city_country: JP
# city_date: 1728598495
# Processing Record 27 of Set 4 | faro
# city_lat: 37.0194
# city_lng: -7.9322
# city_max_temp: 292.03
# city_humidity: 82
# city_clouds: 75
# city_wind: 2.06
# city_country: PT
# city_date: 1728598496
# Processing Record 28 of Set 4 | bridgewater
# city_lat: 44.3835
# city_lng: -64.5155
# city_max_temp: 284.97
# city_humidity: 68
# city_clouds: 23
# city_wind: 5.66
# city_country: CA
# city_date: 1728598497
# Processing Record 29 of Set 4 | deqen
# city_lat: 29.9618
# city_lng: 90.7188
# city_max_temp: 276.45
# city_humidity: 86
# city_clouds: 4
# city_wind: 1.22
# city_country: CN
# city_date: 1728598498
# Processing Record 30 of Set 4 | pachino
# city_lat: 36.7186
# city_lng: 15.0907
# city_max_temp: 296.34
# city_humidity: 77
# city_clouds: 99
# city_wind: 3.2
# city_country: IT
# city_date: 1728598499
# Processing Record 31 of Set 4 | katsuura
# city_lat: 35.1333
# city_lng: 140.3
# city_max_temp: 290.94
# city_humidity: 82
# city_clouds: 77
# city_wind: 5.77
# city_country: JP
# city_date: 1728598500
# Processing Record 32 of Set 4 | ontario
# city_lat: 34.0633
# city_lng: -117.6509
# city_max_temp: 305.71
# city_humidity: 29
# city_clouds: 20
# city_wind: 5.66
# city_country: US
# city_date: 1728598501
# Processing Record 33 of Set 4 | bethel
# city_lat: 41.3712
# city_lng: -73.414
# city_max_temp: 286.79
# city_humidity: 60
# city_clouds: 5
# city_wind: 0.45
# city_country: US
# city_date: 1728598502
# Processing Record 34 of Set 4 | nemuro
# city_lat: 43.3236
# city_lng: 145.575
# city_max_temp: 284.64
# city_humidity: 80
# city_clouds: 100
# city_wind: 11.03
# city_country: JP
# city_date: 1728598504
# Processing Record 35 of Set 4 | iola
# city_lat: 37.9245
# city_lng: -95.4
# city_max_temp: 302.18
# city_humidity: 53
# city_clouds: 0
# city_wind: 2.06
# city_country: US
# city_date: 1728598281
# Processing Record 36 of Set 4 | happy valley-goose bay
# city_lat: 53.3168
# city_lng: -60.3315
# city_max_temp: 281.32
# city_humidity: 100
# city_clouds: 100
# city_wind: 2.06
# city_country: CA
# city_date: 1728598506
# Processing Record 37 of Set 4 | srednebelaya
# city_lat: 50.6594
# city_lng: 128.0106
# city_max_temp: 277.56
# city_humidity: 75
# city_clouds: 100
# city_wind: 5.03
# city_country: RU
# city_date: 1728598334
# Processing Record 38 of Set 4 | solnechnyy
# city_lat: 50.7214
# city_lng: 136.6319
# city_max_temp: 278.04
# city_humidity: 73
# city_clouds: 100
# city_wind: 2.5
# city_country: RU
# city_date: 1728598508
# Processing Record 39 of Set 4 | ulaangom
# city_lat: 49.9811
# city_lng: 92.0667
# city_max_temp: 277.6
# city_humidity: 69
# city_clouds: 20
# city_wind: 1.01
# city_country: MN
# city_date: 1728598509
# Processing Record 40 of Set 4 | tralee
# city_lat: 52.2704
# city_lng: -9.7026
# city_max_temp: 280.57
# city_humidity: 77
# city_clouds: 36
# city_wind: 0.76
# city_country: IE
# city_date: 1728598510
# Processing Record 41 of Set 4 | keflavik
# city_lat: 64.0049
# city_lng: -22.5624
# city_max_temp: 274.39
# city_humidity: 80
# city_clouds: 20
# city_wind: 9.77
# city_country: IS
# city_date: 1728598440
# Processing Record 42 of Set 4 | boguchany
# city_lat: 58.3814
# city_lng: 97.4531
# city_max_temp: 267.84
# city_humidity: 83
# city_clouds: 76
# city_wind: 2.67
# city_country: RU
# city_date: 1728598512
# Processing Record 43 of Set 4 | ocher
# city_lat: 57.8904
# city_lng: 54.7202
# city_max_temp: 268.86
# city_humidity: 69
# city_clouds: 6
# city_wind: 4.9
# city_country: RU
# city_date: 1728598514
# Processing Record 44 of Set 4 | anadyr
# city_lat: 64.75
# city_lng: 177.4833
# city_max_temp: 272.43
# city_humidity: 74
# city_clouds: 20
# city_wind: 5
# city_country: RU
# city_date: 1728598515
# Processing Record 45 of Set 4 | kapuskasing
# city_lat: 49.4169
# city_lng: -82.4331
# city_max_temp: 287.15
# city_humidity: 58
# city_clouds: 75
# city_wind: 2.57
# city_country: CA
# city_date: 1728598516
# Processing Record 46 of Set 4 | uliastay
# city_lat: 47.7417
# city_lng: 96.8444
# city_max_temp: 275.43
# city_humidity: 55
# city_clouds: 5
# city_wind: 2.57
# city_country: MN
# city_date: 1728598517
# Processing Record 47 of Set 4 | tulun
# city_lat: 54.5611
# city_lng: 100.5792
# city_max_temp: 270.89
# city_humidity: 95
# city_clouds: 97
# city_wind: 0.66
# city_country: RU
# city_date: 1728598518
# Processing Record 48 of Set 4 | thunder bay
# city_lat: 48.4001
# city_lng: -89.3168
# city_max_temp: 287.75
# city_humidity: 56
# city_clouds: 97
# city_wind: 2.1
# city_country: CA
# city_date: 1728598407
# Processing Record 49 of Set 4 | khovd
# city_lat: 48.0056
# city_lng: 91.6419
# city_max_temp: 280.6
# city_humidity: 43
# city_clouds: 0
# city_wind: 1.14
# city_country: MN
# city_date: 1728598520
# Processing Record 0 of Set 5 | wisbech
# city_lat: 52.6662
# city_lng: 0.1594
# city_max_temp: 278.16
# city_humidity: 75
# city_clouds: 8
# city_wind: 2.63
# city_country: GB
# city_date: 1728598521
# Processing Record 1 of Set 5 | mysen
# city_lat: 59.5535
# city_lng: 11.3258
# city_max_temp: 277.39
# city_humidity: 93
# city_clouds: 99
# city_wind: 0.45
# city_country: NO
# city_date: 1728598522
# Processing Record 2 of Set 5 | horta
# city_lat: 38.5333
# city_lng: -28.6333
# city_max_temp: 292.6
# city_humidity: 87
# city_clouds: 85
# city_wind: 3.58
# city_country: PT
# city_date: 1728598519
# Processing Record 3 of Set 5 | berezovyy
# city_lat: 51.6667
# city_lng: 135.7
# city_max_temp: 276.33
# city_humidity: 71
# city_clouds: 100
# city_wind: 1.09
# city_country: RU
# city_date: 1728598525
# Processing Record 4 of Set 5 | lianhe
# city_lat: 47.1333
# city_lng: 129.2667
# city_max_temp: 274.28
# city_humidity: 85
# city_clouds: 2
# city_wind: 0.85
# city_country: CN
# city_date: 1728598526
# Processing Record 5 of Set 5 | dubovka
# city_lat: 49.0583
# city_lng: 44.829
# city_max_temp: 282.85
# city_humidity: 77
# city_clouds: 15
# city_wind: 3.81
# city_country: RU
# city_date: 1728598527
# Processing Record 6 of Set 5 | tsetserleg
# city_lat: 47.475
# city_lng: 101.4542
# city_max_temp: 275.43
# city_humidity: 59
# city_clouds: 3
# city_wind: 1.98
# city_country: MN
# city_date: 1728598528
# Processing Record 7 of Set 5 | sitka
# city_lat: 57.0531
# city_lng: -135.33
# city_max_temp: 280.09
# city_humidity: 81
# city_clouds: 100
# city_wind: 5.66
# city_country: US
# city_date: 1728598529
# Processing Record 8 of Set 5 | milford haven
# city_lat: 51.7128
# city_lng: -5.0341
# city_max_temp: 278.21
# city_humidity: 94
# city_clouds: 14
# city_wind: 3.54
# city_country: GB
# city_date: 1728598530
# Processing Record 9 of Set 5 | kovacica
# city_lat: 45.1117
# city_lng: 20.6214
# city_max_temp: 292.01
# city_humidity: 59
# city_clouds: 7
# city_wind: 2.01
# city_country: RS
# city_date: 1728598531
# Processing Record 10 of Set 5 | klyuchi
# city_lat: 52.2667
# city_lng: 79.1667
# city_max_temp: 280.39
# city_humidity: 48
# city_clouds: 100
# city_wind: 8.11
# city_country: RU
# city_date: 1728598533
# Processing Record 11 of Set 5 | tyumen
# city_lat: 57.1522
# city_lng: 65.5272
# city_max_temp: 270.2
# city_humidity: 93
# city_clouds: 100
# city_wind: 6
# city_country: RU
# city_date: 1728598244
# Processing Record 12 of Set 5 | altay
# city_lat: 47.8667
# city_lng: 88.1167
# city_max_temp: 280.19
# city_humidity: 55
# city_clouds: 2
# city_wind: 1.87
# city_country: CN
# city_date: 1728598535
# Processing Record 13 of Set 5 | la sarre
# city_lat: 48.8002
# city_lng: -79.1996
# city_max_temp: 281.07
# city_humidity: 82
# city_clouds: 92
# city_wind: 2.19
# city_country: CA
# city_date: 1728598536
# Processing Record 14 of Set 5 | flin flon
# city_lat: 54.7682
# city_lng: -101.865
# city_max_temp: 286.06
# city_humidity: 47
# city_clouds: 40
# city_wind: 5.14
# city_country: CA
# city_date: 1728598489
# Processing Record 15 of Set 5 | motygino
# city_lat: 58.1831
# city_lng: 94.7592
# city_max_temp: 267.81
# city_humidity: 83
# city_clouds: 13
# city_wind: 2.35
# city_country: RU
# city_date: 1728598538
# Processing Record 16 of Set 5 | ola
# city_lat: 59.5833
# city_lng: 151.2833
# city_max_temp: 271.08
# city_humidity: 66
# city_clouds: 25
# city_wind: 2.39
# city_country: RU
# city_date: 1728598539
# Processing Record 17 of Set 5 | salekhard
# city_lat: 66.53
# city_lng: 66.6019
# city_max_temp: 266.24
# city_humidity: 84
# city_clouds: 13
# city_wind: 1.78
# city_country: RU
# city_date: 1728598541
# Processing Record 18 of Set 5 | whitehorse
# city_lat: 60.7161
# city_lng: -135.0538
# city_max_temp: 279.87
# city_humidity: 67
# city_clouds: 75
# city_wind: 5.66
# city_country: CA
# city_date: 1728598542
# Processing Record 19 of Set 5 | thompson
# city_lat: 55.7435
# city_lng: -97.8558
# city_max_temp: 284.24
# city_humidity: 62
# city_clouds: 75
# city_wind: 3.09
# city_country: CA
# city_date: 1728598543
# Processing Record 20 of Set 5 | aasiaat
# city_lat: 68.7098
# city_lng: -52.8699
# city_max_temp: 267.97
# city_humidity: 68
# city_clouds: 42
# city_wind: 5.39
# city_country: GL
# city_date: 1728598544
# Processing Record 21 of Set 5 | priob'ye
# city_lat: 62.5206
# city_lng: 65.5964
# city_max_temp: 269.43
# city_humidity: 84
# city_clouds: 9
# city_wind: 2.83
# city_country: RU
# city_date: 1728598545
# Processing Record 22 of Set 5 | tura
# city_lat: 25.5198
# city_lng: 90.2201
# city_max_temp: 294.62
# city_humidity: 96
# city_clouds: 27
# city_wind: 1.54
# city_country: IN
# city_date: 1728598546
# Processing Record 23 of Set 5 | suntar
# city_lat: 62.1444
# city_lng: 117.6319
# city_max_temp: 271.44
# city_humidity: 98
# city_clouds: 100
# city_wind: 1.1
# city_country: RU
# city_date: 1728598547
# Processing Record 24 of Set 5 | college
# city_lat: 64.8569
# city_lng: -147.8028
# city_max_temp: 275.12
# city_humidity: 85
# city_clouds: 100
# city_wind: 2.06
# city_country: US
# city_date: 1728598548
# Processing Record 25 of Set 5 | pangody
# city_lat: 65.85
# city_lng: 74.4859
# city_max_temp: 269.93
# city_humidity: 85
# city_clouds: 80
# city_wind: 6.1
# city_country: RU
# city_date: 1728598549
# Processing Record 26 of Set 5 | oppdal
# city_lat: 62.5943
# city_lng: 9.6912
# city_max_temp: 271.22
# city_humidity: 96
# city_clouds: 90
# city_wind: 2.44
# city_country: NO
# city_date: 1728598551
# Processing Record 27 of Set 5 | amga
# city_lat: 60.8953
# city_lng: 131.9608
# city_max_temp: 274.59
# city_humidity: 93
# city_clouds: 100
# city_wind: 1.19
# city_country: RU
# city_date: 1728598552
# Processing Record 28 of Set 5 | vorgashor
# city_lat: 67.5833
# city_lng: 63.95
# city_max_temp: 263.19
# city_humidity: 98
# city_clouds: 49
# city_wind: 0.95
# city_country: RU
# city_date: 1728598553
# Processing Record 29 of Set 5 | bilibino
# city_lat: 68.0546
# city_lng: 166.4372
# city_max_temp: 257.95
# city_humidity: 97
# city_clouds: 65
# city_wind: 1.06
# city_country: RU
# city_date: 1728598554
# Processing Record 30 of Set 5 | igarka
# city_lat: 67.4667
# city_lng: 86.5833
# city_max_temp: 266.35
# city_humidity: 92
# city_clouds: 99
# city_wind: 7.08
# city_country: RU
# city_date: 1728598405
# Processing Record 31 of Set 5 | udachny
# city_lat: 66.4167
# city_lng: 112.4
# city_max_temp: 261.41
# city_humidity: 97
# city_clouds: 99
# city_wind: 1.45
# city_country: RU
# city_date: 1728598556
# Processing Record 32 of Set 5 | iqaluit
# city_lat: 63.7506
# city_lng: -68.5145
# city_max_temp: 274
# city_humidity: 74
# city_clouds: 75
# city_wind: 0
# city_country: CA
# city_date: 1728598557
# Processing Record 33 of Set 5 | olonkinbyen
# city_lat: 70.9221
# city_lng: -8.7187
# city_max_temp: 270.27
# city_humidity: 91
# city_clouds: 100
# city_wind: 20.56
# city_country: SJ
# city_date: 1728598558
# Processing Record 34 of Set 5 | strezhevoy
# city_lat: 60.7333
# city_lng: 77.5889
# city_max_temp: 268.63
# city_humidity: 81
# city_clouds: 37
# city_wind: 3.29
# city_country: RU
# city_date: 1728598428
# Processing Record 35 of Set 5 | tiksi
# city_lat: 71.6872
# city_lng: 128.8694
# city_max_temp: 267.69
# city_humidity: 90
# city_clouds: 100
# city_wind: 1.74
# city_country: RU
# city_date: 1728598561
# Processing Record 36 of Set 5 | yellowknife
# city_lat: 62.456
# city_lng: -114.3525
# city_max_temp: 280.6
# city_humidity: 97
# city_clouds: 75
# city_wind: 4.63
# city_country: CA
# city_date: 1728598497
# Processing Record 37 of Set 5 | ust-nera
# city_lat: 64.5667
# city_lng: 143.2
# city_max_temp: 264.6
# city_humidity: 83
# city_clouds: 85
# city_wind: 1.91
# city_country: RU
# city_date: 1728598563
# Processing Record 38 of Set 5 | ilulissat
# city_lat: 69.2167
# city_lng: -51.1
# city_max_temp: 272.16
# city_humidity: 43
# city_clouds: 61
# city_wind: 2.06
# city_country: GL
# city_date: 1728598564
# Processing Record 39 of Set 5 | beloyarskiy
# city_lat: 63.7119
# city_lng: 66.6722
# city_max_temp: 266.6
# city_humidity: 94
# city_clouds: 12
# city_wind: 1.56
# city_country: RU
# city_date: 1728598355
# Processing Record 40 of Set 5 | isafjordur
# city_lat: 66.0755
# city_lng: -23.124
# city_max_temp: 271.5
# city_humidity: 69
# city_clouds: 99
# city_wind: 5.99
# city_country: IS
# city_date: 1728598566
# Processing Record 41 of Set 5 | labytnangi
# city_lat: 66.6572
# city_lng: 66.4183
# city_max_temp: 265.6
# city_humidity: 87
# city_clouds: 12
# city_wind: 1.73
# city_country: RU
# city_date: 1728598267
# Processing Record 42 of Set 5 | hammerfest
# city_lat: 70.6634
# city_lng: 23.6821
# city_max_temp: 278.4
# city_humidity: 75
# city_clouds: 75
# city_wind: 2.06
# city_country: NO
# city_date: 1728598568
# Processing Record 43 of Set 5 | muravlenko
# city_lat: 63.7898
# city_lng: 74.523
# city_max_temp: 267.57
# city_humidity: 93
# city_clouds: 19
# city_wind: 5.22
# city_country: RU
# city_date: 1728598570
# Processing Record 44 of Set 5 | severo-yeniseyskiy
# city_lat: 60.3725
# city_lng: 93.0408
# city_max_temp: 264.52
# city_humidity: 95
# city_clouds: 100
# city_wind: 1.73
# city_country: RU
# city_date: 1728598571
# Processing Record 45 of Set 5 | longyearbyen
# city_lat: 78.2186
# city_lng: 15.6401
# city_max_temp: 277.06
# city_humidity: 75
# city_clouds: 75
# city_wind: 7.2
# city_country: SJ
# city_date: 1728598572
# Processing Record 46 of Set 5 | polyarnyy
# city_lat: 69.1989
# city_lng: 33.4478
# city_max_temp: 276.51
# city_humidity: 86
# city_clouds: 100
# city_wind: 7.76
# city_country: RU
# city_date: 1728598573
# Processing Record 47 of Set 5 | gadzhiyevo
# city_lat: 69.2551
# city_lng: 33.3362
# city_max_temp: 276.47
# city_humidity: 87
# city_clouds: 100
# city_wind: 7.32
# city_country: RU
# city_date: 1728598574
# Processing Record 48 of Set 5 | dudinka
# city_lat: 69.4058
# city_lng: 86.1778
# city_max_temp: 264.27
# city_humidity: 90
# city_clouds: 57
# city_wind: 5.69
# city_country: RU
# city_date: 1728598575
# Processing Record 49 of Set 5 | talnakh
# city_lat: 69.4865
# city_lng: 88.3972
# city_max_temp: 261.97
# city_humidity: 93
# city_clouds: 44
# city_wind: 4.78
# city_country: RU
# city_date: 1728598576
# Processing Record 0 of Set 6 | nadym
# city_lat: 65.5333
# city_lng: 72.5167
# city_max_temp: 270.22
# city_humidity: 86
# city_clouds: 79
# city_wind: 5.25
# city_country: RU
# city_date: 1728598577
# Processing Record 1 of Set 6 | nar'yan-mar
# city_lat: 67.6713
# city_lng: 53.087
# city_max_temp: 270.28
# city_humidity: 77
# city_clouds: 100
# city_wind: 6.61
# city_country: RU
# city_date: 1728598579
# Processing Record 2 of Set 6 | badger
# city_lat: 64.8
# city_lng: -147.5333
# city_max_temp: 275.08
# city_humidity: 85
# city_clouds: 100
# city_wind: 2.06
# city_country: US
# city_date: 1728598580
# Processing Record 3 of Set 6 | christchurch
# city_lat: -43.5333
# city_lng: 172.6333
# city_max_temp: 289.44
# city_humidity: 60
# city_clouds: 6
# city_wind: 2.06
# city_country: NZ
# city_date: 1728598311
# Processing Record 4 of Set 6 | portland
# city_lat: 45.5234
# city_lng: -122.6762
# city_max_temp: 294.2
# city_humidity: 54
# city_clouds: 40
# city_wind: 2.57
# city_country: US
# city_date: 1728598582
# Processing Record 5 of Set 6 | san julian
# city_lat: 21.0167
# city_lng: -102.1667
# city_max_temp: 297.15
# city_humidity: 22
# city_clouds: 3
# city_wind: 4.69
# city_country: MX
# city_date: 1728598583
# Processing Record 6 of Set 6 | el calafate
# city_lat: -50.3408
# city_lng: -72.2768
# city_max_temp: 280.51
# city_humidity: 63
# city_clouds: 75
# city_wind: 4.89
# city_country: AR
# city_date: 1728598398
# Processing Record 7 of Set 6 | ulladulla
# city_lat: -35.35
# city_lng: 150.4667
# city_max_temp: 289.14
# city_humidity: 69
# city_clouds: 84
# city_wind: 0.88
# city_country: AU
# city_date: 1728598585
# Processing Record 8 of Set 6 | richards bay
# city_lat: -28.783
# city_lng: 32.0377
# city_max_temp: 294.3
# city_humidity: 81
# city_clouds: 23
# city_wind: 7.12
# city_country: ZA
# city_date: 1728598586
# ...
# city_humidity: 57
# city_clouds: 77
# city_wind: 3.5
# city_country: CN
# city_date: 1728598768
# Processing Record 21 of Set 9 | pingliang
# city_lat: 35.5392
# city_lng: 106.6861
# city_max_temp: 283.85
# city_humidity: 70
# city_clouds: 100
# city_wind: 0.74
# city_country: CN
# city_date: 1728598770
# Processing Record 22 of Set 9 | longjiang
# city_lat: 47.3303
# city_lng: 123.1836
# city_max_temp: 276.98
# city_humidity: 45
# city_clouds: 76
# city_wind: 1.21
# city_country: CN
# city_date: 1728598771
# Processing Record 23 of Set 9 | choibalsan
# city_lat: 48.0667
# city_lng: 114.5
# city_max_temp: 272.43
# city_humidity: 63
# city_clouds: 17
# city_wind: 3.2
# city_country: MN
# city_date: 1728598772
# Processing Record 24 of Set 9 | palanga
# city_lat: 55.9175
# city_lng: 21.0686
# city_max_temp: 288.16
# city_humidity: 77
# city_clouds: 75
# city_wind: 4.12
# city_country: LT
# city_date: 1728598773
# Processing Record 25 of Set 9 | grand falls-windsor
# city_lat: 48.9332
# city_lng: -55.6649
# city_max_temp: 283.99
# city_humidity: 83
# city_clouds: 3
# city_wind: 0.12
# city_country: CA
# city_date: 1728598774
# Processing Record 26 of Set 9 | boguchar
# city_lat: 49.9358
# city_lng: 40.545
# city_max_temp: 282.28
# city_humidity: 81
# city_clouds: 50
# city_wind: 2.35
# city_country: RU
# city_date: 1728598742
# Processing Record 27 of Set 9 | omutinskiy
# city_lat: 56.4745
# city_lng: 67.6709
# city_max_temp: 270.2
# city_humidity: 95
# city_clouds: 100
# city_wind: 8.54
# city_country: RU
# city_date: 1728598776
# Processing Record 28 of Set 9 | nuuk
# city_lat: 64.1835
# city_lng: -51.7216
# city_max_temp: 271.49
# city_humidity: 100
# city_clouds: 100
# city_wind: 0.51
# city_country: GL
# city_date: 1728598777
# Processing Record 29 of Set 9 | vernon
# city_lat: 50.2581
# city_lng: -119.2691
# city_max_temp: 289.89
# city_humidity: 34
# city_clouds: 91
# city_wind: 1.03
# city_country: CA
# city_date: 1728598545
# Processing Record 30 of Set 9 | dalmatovo
# city_lat: 56.26
# city_lng: 62.9362
# city_max_temp: 270.51
# city_humidity: 95
# city_clouds: 100
# city_wind: 8.23
# city_country: RU
# city_date: 1728598780
# Processing Record 31 of Set 9 | mirny
# city_lat: 62.5353
# city_lng: 113.9611
# city_max_temp: 270.76
# city_humidity: 91
# city_clouds: 100
# city_wind: 2.49
# city_country: RU
# city_date: 1728598781
# Processing Record 32 of Set 9 | khandyga
# city_lat: 62.6667
# city_lng: 135.6
# city_max_temp: 272.1
# city_humidity: 78
# city_clouds: 100
# city_wind: 2.8
# city_country: RU
# city_date: 1728598782
# Processing Record 33 of Set 9 | sodankyla
# city_lat: 67.4167
# city_lng: 26.6
# city_max_temp: 277.16
# city_humidity: 98
# city_clouds: 100
# city_wind: 5.81
# city_country: FI
# city_date: 1728598783
# Processing Record 34 of Set 9 | malmberget
# city_lat: 67.1753
# city_lng: 20.6549
# city_max_temp: 273.46
# city_humidity: 100
# city_clouds: 100
# city_wind: 1.03
# city_country: SE
# city_date: 1728598784
# Processing Record 35 of Set 9 | saudarkrokur
# city_lat: 65.7461
# city_lng: -19.6394
# city_max_temp: 271.99
# city_humidity: 79
# city_clouds: 73
# city_wind: 6.04
# city_country: IS
# city_date: 1728598661
# Processing Record 36 of Set 9 | dunedin
# city_lat: -45.8742
# city_lng: 170.5036
# city_max_temp: 285.53
# city_humidity: 46
# city_clouds: 19
# city_wind: 0.88
# city_country: NZ
# city_date: 1728598786
# Processing Record 37 of Set 9 | port lincoln
# city_lat: -34.7333
# city_lng: 135.8667
# city_max_temp: 286.09
# city_humidity: 66
# city_clouds: 100
# city_wind: 4.76
# city_country: AU
# city_date: 1728598787
# Processing Record 38 of Set 9 | cidreira
# city_lat: -30.1811
# city_lng: -50.2056
# city_max_temp: 291.59
# city_humidity: 90
# city_clouds: 100
# city_wind: 10.82
# city_country: BR
# city_date: 1728598789
# Processing Record 39 of Set 9 | oranjemund
# city_lat: -28.55
# city_lng: 16.4333
# city_max_temp: 288.09
# city_humidity: 78
# city_clouds: 8
# city_wind: 3.49
# city_country: NA
# city_date: 1728598790
# Processing Record 40 of Set 9 | prieska
# city_lat: -29.6641
# city_lng: 22.7474
# city_max_temp: 296.21
# city_humidity: 17
# city_clouds: 78
# city_wind: 1.94
# city_country: ZA
# city_date: 1728598791
# Processing Record 41 of Set 9 | cannonvale
# city_lat: -20.2833
# city_lng: 148.7
# city_max_temp: 297.81
# city_humidity: 68
# city_clouds: 4
# city_wind: 5.88
# city_country: AU
# city_date: 1728598792
# Processing Record 42 of Set 9 | beira
# city_lat: -19.8436
# city_lng: 34.8389
# city_max_temp: 296.2
# city_humidity: 78
# city_clouds: 20
# city_wind: 4.12
# city_country: MZ
# city_date: 1728598793
# Processing Record 43 of Set 9 | minas de marcona
# city_lat: -15.2119
# city_lng: -75.1103
# city_max_temp: 287.61
# city_humidity: 74
# city_clouds: 32
# city_wind: 7.52
# city_country: PE
# city_date: 1728598794
# Processing Record 44 of Set 9 | toliara
# city_lat: -23.35
# city_lng: 43.6667
# city_max_temp: 296.88
# city_humidity: 70
# city_clouds: 61
# city_wind: 1.92
# city_country: MG
# city_date: 1728598795
# Processing Record 45 of Set 9 | marondera
# city_lat: -18.1853
# city_lng: 31.5519
# city_max_temp: 284.22
# city_humidity: 65
# city_clouds: 0
# city_wind: 1.24
# city_country: ZW
# city_date: 1728598796
# Processing Record 46 of Set 9 | urangan
# city_lat: -25.3
# city_lng: 152.9
# city_max_temp: 293.94
# city_humidity: 70
# city_clouds: 42
# city_wind: 6.77
# city_country: AU
# city_date: 1728598797
# Processing Record 47 of Set 9 | amper
# city_lat: 9.35
# city_lng: 9.7
# city_max_temp: 296.72
# city_humidity: 87
# city_clouds: 16
# city_wind: 0.94
# city_country: NG
# city_date: 1728598799
# Processing Record 48 of Set 9 | puerto leguizamo
# city_lat: -0.1934
# city_lng: -74.7819
# city_max_temp: 299.46
# city_humidity: 83
# city_clouds: 100
# city_wind: 0.91
# city_country: CO
# city_date: 1728598800
# Processing Record 49 of Set 9 | sao felix do xingu
# city_lat: -6.6447
# city_lng: -51.995
# city_max_temp: 306.17
# city_humidity: 24
# city_clouds: 22
# city_wind: 0.7
# city_country: BR
# city_date: 1728598801
# Processing Record 0 of Set 10 | sola
# city_lat: -13.8833
# city_lng: 167.55
# city_max_temp: 299.42
# city_humidity: 78
# city_clouds: 100
# city_wind: 7.42
# city_country: VU
# city_date: 1728598802
# Processing Record 1 of Set 10 | alotau
# city_lat: -10.3069
# city_lng: 150.4462
# city_max_temp: 298.83
# city_humidity: 93
# city_clouds: 99
# city_wind: 2.17
# city_country: PG
# city_date: 1728598803
# Processing Record 2 of Set 10 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 3 of Set 10 | leava
# city_lat: -14.3
# city_lng: -178.1667
# city_max_temp: 300.25
# city_humidity: 79
# city_clouds: 85
# city_wind: 4.08
# city_country: WF
# city_date: 1728598514
# Processing Record 4 of Set 10 | likiep
# city_lat: 9.8251
# city_lng: 169.3107
# city_max_temp: 301.07
# city_humidity: 75
# city_clouds: 100
# city_wind: 3.17
# city_country: MH
# city_date: 1728598807
# Processing Record 5 of Set 10 | colonia
# city_lat: 50.9333
# city_lng: 6.95
# city_max_temp: 284.24
# city_humidity: 91
# city_clouds: 40
# city_wind: 4.63
# city_country: DE
# city_date: 1728598516
# Processing Record 6 of Set 10 | ponto novo
# city_lat: -10.8628
# city_lng: -40.1336
# city_max_temp: 304.32
# city_humidity: 30
# city_clouds: 73
# city_wind: 5.14
# city_country: BR
# city_date: 1728598809
# Processing Record 7 of Set 10 | ixtapa
# city_lat: 20.7
# city_lng: -105.2
# city_max_temp: 304.39
# city_humidity: 74
# city_clouds: 40
# city_wind: 5.14
# city_country: MX
# city_date: 1728598810
# Processing Record 8 of Set 10 | lisala
# city_lat: 2.15
# city_lng: 21.5167
# city_max_temp: 294.81
# city_humidity: 96
# city_clouds: 97
# city_wind: 0.57
# city_country: CD
# city_date: 1728598579
# Processing Record 9 of Set 10 | yurimaguas
# city_lat: -5.9
# city_lng: -76.0833
# city_max_temp: 306.26
# city_humidity: 44
# city_clouds: 95
# city_wind: 1.04
# city_country: PE
# city_date: 1728598634
# Processing Record 10 of Set 10 | manokwari
# city_lat: -0.8667
# city_lng: 134.0833
# city_max_temp: 300.3
# city_humidity: 77
# city_clouds: 68
# city_wind: 1.95
# city_country: ID
# city_date: 1728598813
# Processing Record 11 of Set 10 | hobyo
# city_lat: 5.3505
# city_lng: 48.5268
# city_max_temp: 298.67
# city_humidity: 82
# city_clouds: 96
# city_wind: 9.48
# city_country: SO
# city_date: 1728598815
# Processing Record 12 of Set 10 | funafuti
# city_lat: -8.5243
# city_lng: 179.1942
# city_max_temp: 304.15
# city_humidity: 79
# city_clouds: 20
# city_wind: 3.6
# city_country: TV
# city_date: 1728598816
# Processing Record 13 of Set 10 | taulaga
# city_lat: -11.0553
# city_lng: -171.0883
# city_max_temp: 301.13
# city_humidity: 76
# city_clouds: 68
# city_wind: 5.88
# city_country: AS
# city_date: 1728598817
# Processing Record 14 of Set 10 | trenggalek
# city_lat: -8.05
# city_lng: 111.7167
# city_max_temp: 297.22
# city_humidity: 98
# city_clouds: 75
# city_wind: 1.23
# city_country: ID
# city_date: 1728598610
# Processing Record 15 of Set 10 | mana
# city_lat: 5.6592
# city_lng: -53.7767
# city_max_temp: 300.09
# city_humidity: 83
# city_clouds: 99
# city_wind: 4.25
# city_country: GF
# city_date: 1728598819
# Processing Record 16 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 17 of Set 10 | ormara
# city_lat: 25.2088
# city_lng: 64.6357
# city_max_temp: 300.65
# city_humidity: 76
# city_clouds: 0
# city_wind: 4.93
# city_country: PK
# city_date: 1728598821
# Processing Record 18 of Set 10 | tamanrasset
# city_lat: 22.785
# city_lng: 5.5228
# city_max_temp: 299.1
# city_humidity: 24
# city_clouds: 40
# city_wind: 1.54
# city_country: DZ
# city_date: 1728598822
# Processing Record 19 of Set 10 | arteche
# city_lat: 12.2645
# city_lng: 125.4048
# city_max_temp: 298.36
# city_humidity: 93
# city_clouds: 51
# city_wind: 1.09
# city_country: PH
# city_date: 1728598823
# Processing Record 20 of Set 10 | i-n-salah
# city_lat: 27.1935
# city_lng: 2.4607
# city_max_temp: 306.59
# city_humidity: 22
# city_clouds: 0
# city_wind: 3.2
# city_country: DZ
# city_date: 1728598825
# Processing Record 21 of Set 10 | la'ie
# city_lat: 21.6477
# city_lng: -157.9253
# city_max_temp: 303.81
# city_humidity: 74
# city_clouds: 53
# city_wind: 5.32
# city_country: US
# city_date: 1728598826
# Processing Record 22 of Set 10 | paris
# city_lat: 48.8534
# city_lng: 2.3488
# city_max_temp: 284.92
# city_humidity: 93
# city_clouds: 75
# city_wind: 2.57
# city_country: FR
# city_date: 1728598719
# Processing Record 23 of Set 10 | mersa matruh
# city_lat: 31.3525
# city_lng: 27.2453
# city_max_temp: 296.91
# city_humidity: 62
# city_clouds: 1
# city_wind: 2.01
# city_country: EG
# city_date: 1728598828
# Processing Record 24 of Set 10 | la junta
# city_lat: 37.985
# city_lng: -103.5438
# city_max_temp: 304.31
# city_humidity: 11
# city_clouds: 0
# city_wind: 3.09
# city_country: US
# city_date: 1728598829
# Processing Record 25 of Set 10 | xilin hot
# city_lat: 43.9667
# city_lng: 116.0333
# city_max_temp: 279.67
# city_humidity: 63
# city_clouds: 42
# city_wind: 2.28
# city_country: CN
# city_date: 1728598830
# Processing Record 26 of Set 10 | xining
# city_lat: 36.6167
# city_lng: 101.7667
# city_max_temp: 280.48
# city_humidity: 77
# city_clouds: 89
# city_wind: 1.35
# city_country: CN
# city_date: 1728598831
# Processing Record 27 of Set 10 | st. john's
# city_lat: 47.5649
# city_lng: -52.7093
# city_max_temp: 284.8
# city_humidity: 96
# city_clouds: 75
# city_wind: 2.57
# city_country: CA
# city_date: 1728598631
# Processing Record 28 of Set 10 | oneonta
# city_lat: 42.4529
# city_lng: -75.0638
# city_max_temp: 281.6
# city_humidity: 81
# city_clouds: 96
# city_wind: 4.35
# city_country: US
# city_date: 1728598784
# Processing Record 29 of Set 10 | hauterive
# city_lat: 46.0901
# city_lng: 3.4459
# city_max_temp: 283.5
# city_humidity: 90
# city_clouds: 93
# city_wind: 1.74
# city_country: FR
# city_date: 1728598835
# Processing Record 30 of Set 10 | okhotsk
# city_lat: 59.3833
# city_lng: 143.3
# city_max_temp: 277.24
# city_humidity: 89
# city_clouds: 100
# city_wind: 6.41
# city_country: RU
# city_date: 1728598836
# Processing Record 31 of Set 10 | usinsk
# city_lat: 65.9939
# city_lng: 57.5281
# city_max_temp: 263.97
# city_humidity: 94
# city_clouds: 21
# city_wind: 2.24
# city_country: RU
# city_date: 1728598837
# Processing Record 32 of Set 10 | fort mcmurray
# city_lat: 56.7268
# city_lng: -111.381
# city_max_temp: 286.92
# city_humidity: 38
# city_clouds: 100
# city_wind: 6.17
# city_country: CA
# city_date: 1728598838
# Processing Record 33 of Set 10 | new norfolk
# city_lat: -42.7826
# city_lng: 147.0587
# city_max_temp: 286.44
# city_humidity: 60
# city_clouds: 66
# city_wind: 5.44
# city_country: AU
# city_date: 1728598839
# Processing Record 34 of Set 10 | las heras
# city_lat: -46.5419
# city_lng: -68.9359
# city_max_temp: 283.8
# city_humidity: 37
# city_clouds: 77
# city_wind: 10.45
# city_country: AR
# city_date: 1728598840
# Processing Record 35 of Set 10 | whakatane
# city_lat: -37.9585
# city_lng: 176.9854
# city_max_temp: 291.21
# city_humidity: 71
# city_clouds: 87
# city_wind: 1.79
# city_country: NZ
# city_date: 1728598841
# Processing Record 36 of Set 10 | amassoma
# city_lat: 4.9692
# city_lng: 6.1097
# city_max_temp: 297.8
# city_humidity: 94
# city_clouds: 51
# city_wind: 1.73
# city_country: NG
# city_date: 1728598843
# Processing Record 37 of Set 10 | luanda
# city_lat: -8.8368
# city_lng: 13.2343
# city_max_temp: 298.15
# city_humidity: 83
# city_clouds: 40
# city_wind: 3.6
# city_country: AO
# city_date: 1728598560
# Processing Record 38 of Set 10 | port blair
# city_lat: 11.6667
# city_lng: 92.75
# city_max_temp: 300.11
# city_humidity: 76
# city_clouds: 32
# city_wind: 0.71
# city_country: IN
# city_date: 1728598845
# Processing Record 39 of Set 10 | kourou
# city_lat: 5.1552
# city_lng: -52.6478
# city_max_temp: 299.82
# city_humidity: 80
# city_clouds: 64
# city_wind: 2.69
# city_country: GF
# city_date: 1728598846
# Processing Record 40 of Set 10 | gimbi
# city_lat: 9.1667
# city_lng: 35.8333
# city_max_temp: 286.23
# city_humidity: 99
# city_clouds: 100
# city_wind: 0.87
# city_country: ET
# city_date: 1728598847
# Processing Record 41 of Set 10 | la passe
# city_lat: 45.5549
# city_lng: -0.8967
# city_max_temp: 287.27
# city_humidity: 82
# city_clouds: 32
# city_wind: 3.16
# city_country: FR
# city_date: 1728598848
# Processing Record 42 of Set 10 | nasugbu
# city_lat: 14.1
# city_lng: 120.6833
# city_max_temp: 297.3
# city_humidity: 89
# city_clouds: 3
# city_wind: 1.35
# city_country: PH
# city_date: 1728598849
# Processing Record 43 of Set 10 | oriximina
# city_lat: -1.7656
# city_lng: -55.8661
# city_max_temp: 304.59
# city_humidity: 42
# city_clouds: 89
# city_wind: 1.63
# city_country: BR
# city_date: 1728598850
# Processing Record 44 of Set 10 | lata
# city_lat: 40.1629
# city_lng: -8.3327
# city_max_temp: 286.4
# city_humidity: 75
# city_clouds: 52
# city_wind: 1.49
# city_country: PT
# city_date: 1728598852
# Processing Record 45 of Set 10 | ilha de mocambique
# city_lat: -15.0342
# city_lng: 40.7358
# city_max_temp: 297.37
# city_humidity: 74
# city_clouds: 0
# city_wind: 2.23
# city_country: MZ
# city_date: 1728598853
# Processing Record 46 of Set 10 | trincomalee
# city_lat: 8.5711
# city_lng: 81.2335
# city_max_temp: 298.59
# city_humidity: 86
# city_clouds: 76
# city_wind: 5.83
# city_country: LK
# city_date: 1728598854
# Processing Record 47 of Set 10 | alaghsas
# city_lat: 17.0187
# city_lng: 8.0168
# city_max_temp: 305.25
# city_humidity: 12
# city_clouds: 22
# city_wind: 3.45
# city_country: NE
# city_date: 1728598796
# Processing Record 48 of Set 10 | niafunke
# city_lat: 15.9322
# city_lng: -3.9906
# city_max_temp: 308.31
# city_humidity: 22
# city_clouds: 82
# city_wind: 2.2
# city_country: ML
# city_date: 1728598856
# Processing Record 49 of Set 10 | nouadhibou
# city_lat: 20.931
# city_lng: -17.0347
# city_max_temp: 299.14
# city_humidity: 61
# city_clouds: 20
# city_wind: 3.09
# city_country: MR
# city_date: 1728598857
# Processing Record 0 of Set 11 | quartz hill
# city_lat: 34.6453
# city_lng: -118.2181
# city_max_temp: 306.15
# city_humidity: 17
# city_clouds: 0
# city_wind: 5.81
# city_country: US
# city_date: 1728598858
# Processing Record 1 of Set 11 | chadron
# city_lat: 42.8294
# city_lng: -102.9999
# city_max_temp: 304.97
# city_humidity: 12
# city_clouds: 0
# city_wind: 2.06
# city_country: US
# city_date: 1728598859
# Processing Record 2 of Set 11 | rikaze
# city_lat: 29.25
# city_lng: 88.8833
# city_max_temp: 280.97
# city_humidity: 54
# city_clouds: 45
# city_wind: 1.48
# city_country: CN
# city_date: 1728598732
# Processing Record 3 of Set 11 | boulder
# city_lat: 40.0833
# city_lng: -105.3505
# city_max_temp: 298.6
# city_humidity: 19
# city_clouds: 0
# city_wind: 3.09
# city_country: US
# city_date: 1728598713
# Processing Record 4 of Set 11 | clarinda
# city_lat: 40.7419
# city_lng: -95.0383
# city_max_temp: 302.04
# city_humidity: 26
# city_clouds: 0
# city_wind: 5.66
# city_country: US
# city_date: 1728598863
# Processing Record 5 of Set 11 | alesund
# city_lat: 62.4723
# city_lng: 6.1549
# city_max_temp: 279.23
# city_humidity: 65
# city_clouds: 40
# city_wind: 2.57
# city_country: NO
# city_date: 1728598864
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#print(city_data)
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# convert max tem to degrees celsious from degrees kelvin
city_data_df["Max Temp (deg C)"] = city_data_df["Max Temp"] - 273.25

# Show Record Count
city_data_df.count()
# Out:
# City                484
# Lat                 484
# Lng                 484
# Max Temp            484
# Humidity            484
# Cloudiness          484
# Wind Speed          484
# Country             484
# Date                484
# Max Temp (deg C)    484
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0  edinburgh of the seven seas -37.0676  -12.3116    286.01        76
# 1            port-aux-francais -49.3500   70.2167    274.83        94
# 2                      ushuaia -54.8000  -68.3000    278.17        84
# 3                   bredasdorp -34.5322   20.0403    285.71        82
# 4                    adamstown -25.0660 -130.1015    294.28        86
#
#    Cloudiness  Wind Speed Country        Date  Max Temp (deg C)
# 0          38       12.84      SH  1728598298             12.76
# 1          83       17.55      TF  1728598026              1.58
# 2          99        1.33      AR  1728598150              4.92
# 3         100        2.10      ZA  1728598301             12.46
# 4         100        7.72      PN  1728598302             21.03

# %%
print(f"max latitude: {max(city_data_df['Lat'])}")
print(f"min latitude: {min(city_data_df['Lat'])}")
print(f"cwd: {os.getcwd()}")
# Out:
# max latitude: 78.2186
# min latitude: -54.8
# cwd: /Users/wayne.mitchell/Documents/NU/python-api-challenge/WeatherPy

# %%
# Export the City_Data into a csv
city_data_df.to_csv("./output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        edinburgh of the seven seas -37.0676  -12.3116    286.01        76
# 1                  port-aux-francais -49.3500   70.2167    274.83        94
# 2                            ushuaia -54.8000  -68.3000    278.17        84
# 3                         bredasdorp -34.5322   20.0403    285.71        82
# 4                          adamstown -25.0660 -130.1015    294.28        86
#
#          Cloudiness  Wind Speed Country        Date  Max Temp (deg C)
# City_ID
# 0                38       12.84      SH  1728598298             12.76
# 1                83       17.55      TF  1728598026              1.58
# 2                99        1.33      AR  1728598150              4.92
# 3               100        2.10      ZA  1728598301             12.46
# 4               100        7.72      PN  1728598302             21.03

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
the_plot = city_data_df.plot.scatter(x= 'Lat', y = 'Max Temp (deg C)')

# Incorporate the other graph properties
the_plot.set(xlabel="Latitude")

# get current current_yyyymmdd 
current_date = datetime.today().strftime('%Y-%m-%d')
the_plot.set(title = f"City Latitude vs. Temperature {current_date }")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
the_plot = city_data_df.plot.scatter(x= 'Lat', y = 'Humidity')

# Incorporate the other graph properties
the_plot.set(title = f"City Latitude vs. Humidity {current_date }")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
the_plot = city_data_df.plot.scatter(x= 'Lat', y = 'Cloudiness')

# Incorporate the other graph properties
the_plot.set(title = f"City Latitude vs. Cloudiness {current_date }")
the_plot.set(xlabel="Latitude")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Build the scatter plots for latitude vs. wind speed
the_plot = city_data_df.plot.scatter(x= 'Lat', y = 'Wind Speed')

# Incorporate the other graph properties
# Incorporate the other graph properties
the_plot.set(title = f"City Latitude vs. Wind Speed {current_date }")
the_plot.set(xlabel="Latitude")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Define a function to create Linear Regression plots
def regress(x_values_series, y_values_series):
    # calculate linear regression from two series, 
    # return a dictionary, keys: slope, intercept, r_val, p_val, std_error, fit, r_squared, line_equation
    # requires from scipy.stats import linregress
    slope, intercept, r_val, p_val, std_error = st.linregress(x_values_series, y_values_series)

    fit = slope * x_values_series + intercept
    r_squared = r_val ** 2
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    regression_results = {
        "slope": slope,
        "intercept": intercept,
        "r_val": r_val,
        "p_val": p_val, 
        "std_error": std_error,
        "fit": fit,
        "r_squared": r_squared,
        "line_equation": line_eq}
    return regression_results

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]
northern_hemi_df.shape
# Out:
# (326, 10)

# %%
# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 12           albany  42.6001 -73.9662    283.47        64          12
# 18       constantia  44.1833  28.6500    289.65        63          72
# 21          stanley  54.8680  -1.6985    275.16        88           0
# 27             sale  34.0389  -6.8166    292.53        94          10
# 32         kingston  17.9970 -76.7936    303.80        77          95
#
#          Wind Speed Country        Date  Max Temp (deg C)
# City_ID
# 12             1.34      US  1728598123             10.22
# 18             2.02      RO  1728598318             16.40
# 21             2.06      GB  1728598098              1.91
# 27             0.00      MA  1728598328             19.28
# 32             1.53      JM  1728598319             30.55

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]
southern_hemi_df.shape
# Out:
# (158, 10)

# %%
# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        edinburgh of the seven seas -37.0676  -12.3116    286.01        76
# 1                  port-aux-francais -49.3500   70.2167    274.83        94
# 2                            ushuaia -54.8000  -68.3000    278.17        84
# 3                         bredasdorp -34.5322   20.0403    285.71        82
# 4                          adamstown -25.0660 -130.1015    294.28        86
#
#          Cloudiness  Wind Speed Country        Date  Max Temp (deg C)
# City_ID
# 0                38       12.84      SH  1728598298             12.76
# 1                83       17.55      TF  1728598026              1.58
# 2                99        1.33      AR  1728598150              4.92
# 3               100        2.10      ZA  1728598301             12.46
# 4               100        7.72      PN  1728598302             21.03

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
regression_values = regress(northern_hemi_df["Lat"],northern_hemi_df["Max Temp (deg C)"])
print(regression_values)
slope = regression_values['slope']
intercept = regression_values['intercept'] 
r_val = regression_values['r_val']
p_val = regression_values['p_val'] 
std_error = regression_values['std_error'] 
fit = regression_values['fit'] 
r_squared = regression_values['r_squared']
r_sqr_round = round(r_squared,2)
line_equation = regression_values['line_equation'] 

print(f"The r-squared value is: {r_squared}")
latitude = northern_hemi_df["Lat"]
temp = northern_hemi_df["Max Temp (deg C)"]
plt.scatter(latitude, temp)
plt.plot(latitude,fit,"r--")

plt.annotate(line_equation,(5,-9),fontsize=15,color="red")
r2 = "r^2 = " + str(r_sqr_round)
plt.annotate(r2,(5, -13),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (deg C)")
plt.title("Northern Hemisphere Maximum Temperature versus Latitude")
plt.show()
# Out:
# {'slope': -0.5006910136220062, 'intercept': 34.02190236151408, 'r_val': -0.8255323675229128, 'p_val': 1.705656681899999e-82, 'std_error': 0.019015834482742123, 'fit': City_ID
# 12     12.692415
# 18     11.899721
# 21      6.549988
# 27     16.978931
# 32     25.010966
#          ...
# 479    12.577607
# 480    19.376690
# 481    13.952554
# 482    13.622799
# 483     2.742583
# Name: Lat, Length: 326, dtype: float64, 'r_squared': 0.6815036898279856, 'line_equation': 'y = -0.5x + 34.02'}
# The r-squared value is: 0.6815036898279856

# %%
# Linear regression on Southern Hemisphere
regression_values = regress(southern_hemi_df["Lat"],southern_hemi_df["Max Temp (deg C)"])
print(regression_values)
slope = regression_values['slope']
intercept = regression_values['intercept'] 
r_val = regression_values['r_val']
p_val = regression_values['p_val'] 
std_error = regression_values['std_error'] 
fit = regression_values['fit'] 
r_squared = regression_values['r_squared']
r_sqr_round = round(r_squared,2)
line_equation = regression_values['line_equation'] 

print(f"The r-squared value is: {r_squared}")
latitude = southern_hemi_df["Lat"]
temp = southern_hemi_df["Max Temp (deg C)"]
plt.scatter(latitude, temp)
plt.plot(latitude,fit,"r-")

plt.annotate(line_equation,(-25, 6),fontsize=15,color="red")
r2 = "r^2 = " + str(r_sqr_round)
plt.annotate(r2,(-25, 3),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (deg C)")
plt.title("Southern Hemisphere Maximum Temperature versus Latitude")
plt.show()
# Out:
# {'slope': 0.39132851438240446, 'intercept': 29.0446156897622, 'r_val': 0.8253759056596661, 'p_val': 1.4333709577399782e-40, 'std_error': 0.021431651983343417, 'fit': City_ID
# 0      14.539007
# 1       9.732554
# 2       7.599813
# 3      15.531181
# 4      19.235575
#          ...
# 462    10.831443
# 463    14.190372
# 465    25.586524
# 471    28.353686
# 473    23.161305
# Name: Lat, Length: 158, dtype: float64, 'r_squared': 0.6812453856435141, 'line_equation': 'y = 0.39x + 29.04'}
# The r-squared value is: 0.6812453856435141

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.007659599322853922

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.00014367159540169783

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.006456908379763574

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.018616831531634456

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.0017236249523139959

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.06495869418886388

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
