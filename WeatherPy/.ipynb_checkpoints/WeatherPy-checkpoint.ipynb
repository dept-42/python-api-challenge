# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st 
import os
import random

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
print(f"weather api key: {weather_api_key}")
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# weather api key: 99d9c9c3906f8432242946870f7f1b5c

# %%
print(f"cwd: {os.getcwd()}")
# Out:
# cwd: /Users/wayne.mitchell/Documents/NU/python-api-challenge/WeatherPy

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '__pycache__',
#  'WeatherPy.ipynb',
#  '.ipynb_checkpoints',
#  'api_keys.py']

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)


# check for about equal number of cities in northern and southern hemisphere
# and total > 1500
lat_lngs_list = list(zip(lats, lngs))

northCount = 0
southCount = 0
for i in lat_lngs_list:
    if i[0] >= 0:
        northCount += 1
    else:
        southCount += 1
print(f"northCount: {northCount}, southCount: {southCount} total: {northCount + southCount}")
# Out:
# northCount: 744, southCount: 756 total: 1500

# %%
# create bins of latitude

# make a lat, lng dict for later recovery of lan values
# and a lat list for input to 'cut'
lat_lng_dict = {}
lat_list = []
for i in lat_lngs_list:
    lat = i[0]
    lng = i[1]
    lat_lng_dict[round(lat,3)] = round(lng,3)
    lat_list.append(round(lat,3))
    
s_75_90 = []
s_60_75 = []
s_45_60 = []
s_30_45 = []
s_15_30 = []
s_0_15  = []
n_0_15  = []
n_15_30 = []
n_30_45 = []
n_45_60 = []
n_60_75 = []
n_75_90 = []


#make latitude bins of 15 degrees
for lat in lat_list:
    if lat <= -90.0:
        s_75_90.append(lat)
        
    elif lat <= -75.0:
        s_60_75.append(lat)
        
    elif lat <= -60.0:
        s_45_60.append(lat) 
        
    elif lat <= -45.0:
        s_30_45.append(lat)
        
    elif lat <= -30.0:
        s_15_30.append(lat) 
        
    elif lat <= -15.0:
        s_0_15.append(lat)
        
    elif lat <= 15.0:
        n_0_15.append(lat)
        
    elif lat <= 30.0:
        n_15_30.append(lat)  
        
    elif lat <= 45.0:
        n_30_45.append(lat)
        
    elif lat <= 60.0:
        n_45_60.append(lat)
        
    elif lat <= 75.0:
        n_60_75.append(lat)
        
    else:
        n_75_90.append(lat)
        
latitude_bands = [s_75_90, \
                  s_60_75, \
                  s_45_60, \
                  s_30_45, \
                  s_15_30, \
                  s_0_15, \
                  n_0_15, \
                  n_15_30, \
                  n_30_45, \
                  n_45_60, \
                  n_60_75, \
                  n_75_90]
print(len(latitude_bands))
print(f"count of s_75_90: {len(s_75_90)}")
print(f"count of s_60_75: {len(s_60_75)}")
print(f"count of s_45_60: {len(s_45_60)}")
print(f"count of s_30_45: {len(s_30_45)}")
print(f"count of s_15_30: {len(s_15_30)}")
print(f"count of s_0_15: {len(s_0_15)}")
print(f"count of n_0_15: {len(n_0_15)}")
print(f"count of n_15_30: {len(n_15_30)}")
print(f"count of n_30_45: {len(n_30_45)}")
print(f"count of n_45_60: {len(n_45_60)}")
print(f"count of n_60_75: {len(n_60_75)}")
print(f"count of n_75_90: {len(n_75_90)}")

#print(latitude_bands)
# Out:
# 12
# count of s_75_90: 0
# count of s_60_75: 150
# count of s_45_60: 123
# count of s_30_45: 123
# count of s_15_30: 119
# count of s_0_15: 123
# count of n_0_15: 259
# count of n_15_30: 123
# count of n_30_45: 113
# count of n_45_60: 135
# count of n_60_75: 115
# count of n_75_90: 117

# %%
# Discard extreme south, count of s_75_90: 0, nothing there, leaves 11 bands.
# collect 49 random latitudes from each list (49 X 11 = 501, so adjust to 501 from 500)

# remove first empty sublist
print(len(latitude_bands))
latitude_bands.pop(0)
print(len(latitude_bands))
latitude_bands_reduced = []
sample_size = 49
city_count = 0
loop_index = 1
cities = []
while city_count < 500:
    print(f"loop index: {loop_index}")
    loop_index += 1
    for lat_band in latitude_bands:
        #print(lat_band)
        if len(lat_band) < sample_size:
            lat_bandr = lat_band
        else:
            lat_bandr =  random.sample(lat_band, sample_size)
            #print(type(lat_bandr))
            #print(lat_band)
            #print(f"number of lats now: {len(lat_band)}")

        # trim to 49 elements
        if len(lat_bandr) > 49:
            lat_bandr = random.sample(lat_bandr, 49)
            
        latitude_bands_reduced.append(list(lat_bandr))
        
    print(f"elements  in latitude_bands_reduced: {len(latitude_bands_reduced)}")
    type(latitude_bands_reduced)
        
    # Empty list for holding the cities names
    
    for lat_band in latitude_bands_reduced:
        #print(type(lat_band))
        for lat in lat_band:
            #print(lat)
            lng = lat_lng_dict[lat]
            city = citipy.nearest_city(lat, lng).city_name
            if city not in cities:
                cities.append(city)
    city_count = len(cities)

#cities = random.sample(cities , 500)
# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
print(cities)
# Out:
# 12
# 11
# loop index: 1
# elements  in latitude_bands_reduced: 11
# loop index: 2
# elements  in latitude_bands_reduced: 22
# loop index: 3
# elements  in latitude_bands_reduced: 33
# loop index: 4
# elements  in latitude_bands_reduced: 44
# loop index: 5
# elements  in latitude_bands_reduced: 55
# Number of cities in the list: 519
# ...

# %%
#print("test url")
#print(f"weather_api_key: {weather_api_key}")
#url = "http://api.openweathermap.org/data/2.5/weather?"
#units = "metric"
##base_url = f"{url}appid={api_key}&units={units}&q="
#test_url = f"{url}appid={weather_api_key}&{units}&q=" + "Paris"
#print(f"this works: http://api.openweathermap.org/data/2.5/weather?appid=99d9c9c3906f8432242946870f7f1b5c&units=metric&q=Paris")
#print(f"test_url: {test_url}")
#print(requests.get(test_url))
#city_weather = requests.get(test_url).json()
#city_lat = city_weather['coord']['lat']
#city_lng = city_weather['coord']['lon']
#city_max_temp = city_weather['main']['temp_max']
#city_humidity = city_weather['main']['humidity']
#city_clouds = city_weather['clouds']['all']
#city_wind = city_weather['wind']['speed']
#city_country = city_weather['sys']['country']
#city_date = city_weather['dt']
#
#print(f"city_lat: {city_lat}")
#print(f"city_lng: {city_lng}")
#print(f"city_max_temp: {city_max_temp}")
#print(f"city_humidity: {city_humidity}")
#print(f"city_clouds: {city_clouds}")
#print(f"city_wind: {city_wind}")
#print(f"city_country: {city_country}")
#print(f"city_date: {city_date}")

# %%
## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude

### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
print(weather_api_key)
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&{units}&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        print(f"city_lat: {city_lat}")
        print(f"city_lng: {city_lng}")
        print(f"city_max_temp: {city_max_temp}")
        print(f"city_humidity: {city_humidity}")
        print(f"city_clouds: {city_clouds}")
        print(f"city_wind: {city_wind}")
        print(f"city_country: {city_country}")
        print(f"city_date: {city_date}")
        

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# 99d9c9c3906f8432242946870f7f1b5c
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# city_lat: 42.6001
# city_lng: -73.9662
# city_max_temp: 278.51
# city_humidity: 68
# city_clouds: 78
# city_wind: 1.79
# city_country: US
# city_date: 1729049637
# Processing Record 2 of Set 1 | port-aux-francais
# city_lat: -49.35
# city_lng: 70.2167
# city_max_temp: 273.75
# city_humidity: 70
# city_clouds: 87
# city_wind: 16.18
# city_country: TF
# city_date: 1729049639
# Processing Record 3 of Set 1 | adamstown
# city_lat: -25.066
# city_lng: -130.1015
# city_max_temp: 294.42
# city_humidity: 88
# city_clouds: 98
# city_wind: 6.71
# city_country: PN
# city_date: 1729049640
# Processing Record 4 of Set 1 | grytviken
# city_lat: -54.2811
# city_lng: -36.5092
# city_max_temp: 276.22
# city_humidity: 77
# city_clouds: 100
# city_wind: 2.93
# city_country: GS
# city_date: 1729049641
# Processing Record 5 of Set 1 | ushuaia
# city_lat: -54.8
# ...

# %%
#print(city_data)
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          497
# Lat           497
# Lng           497
# Max Temp      497
# Humidity      497
# Cloudiness    497
# Wind Speed    497
# Country       497
# Date          497
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             albany  42.6001  -73.9662    278.51        68          78
# 1  port-aux-francais -49.3500   70.2167    273.75        70          87
# 2          adamstown -25.0660 -130.1015    294.42        88          98
# 3          grytviken -54.2811  -36.5092    276.22        77         100
# 4            ushuaia -54.8000  -68.3000    278.96        61          40
#
#    Wind Speed Country        Date
# 0        1.79      US  1729049637
# 1       16.18      TF  1729049639
# 2        6.71      PN  1729049640
# 3        2.93      GS  1729049641
# 4       11.32      AR  1729049518

# %%
print(f"max latitude: {max(city_data_df['Lat'])}")
print(f"min latitude: {min(city_data_df['Lat'])}")
print(f"cwd: {os.getcwd()}")
# Out:
# max latitude: 78.2186
# min latitude: -54.8
# cwd: /Users/wayne.mitchell/Documents/NU/python-api-challenge/WeatherPy

# %%
# change degrees lelvin to degrees celsius
city_data_df['Max Temp'] = city_data_df['Max Temp'] - 273.15
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   albany  42.6001  -73.9662      5.36        68          78
# 1        port-aux-francais -49.3500   70.2167      0.60        70          87
# 2                adamstown -25.0660 -130.1015     21.27        88          98
# 3                grytviken -54.2811  -36.5092      3.07        77         100
# 4                  ushuaia -54.8000  -68.3000      5.81        61          40
#
#          Wind Speed Country        Date
# City_ID
# 0              1.79      US  1729049637
# 1             16.18      TF  1729049639
# 2              6.71      PN  1729049640
# 3              2.93      GS  1729049641
# 4             11.32      AR  1729049518

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   albany  42.6001  -73.9662      5.36        68          78
# 1        port-aux-francais -49.3500   70.2167      0.60        70          87
# 2                adamstown -25.0660 -130.1015     21.27        88          98
# 3                grytviken -54.2811  -36.5092      3.07        77         100
# 4                  ushuaia -54.8000  -68.3000      5.81        61          40
#
#          Wind Speed Country        Date
# City_ID
# 0              1.79      US  1729049637
# 1             16.18      TF  1729049639
# 2              6.71      PN  1729049640
# 3              2.93      GS  1729049641
# 4             11.32      AR  1729049518

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
ax = city_data_df.plot.scatter(x = 'Lat', y = 'Max Temp', c = 'DarkBlue', title = 'Latitude Vs. Temperature')

# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Temperature')

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
ax = city_data_df.plot.scatter(x = 'Lat', y = 'Humidity', c = 'DarkBlue', title = 'Latitude Vs. Humidity')

# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity')

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
ax = city_data_df.plot.scatter(x = 'Lat', y = 'Cloudiness', c = 'DarkBlue', title = 'Latitude Vs. Cloudiness')

# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness')

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
ax = city_data_df.plot.scatter(x = 'Lat', y = 'Wind Speed', c = 'DarkBlue', title = 'Latitude Vs. Wind Speed')

# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed')

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
def regress(x,y):
    regress_vals = st.linregress(x,y)
    slope = regress_vals[0]
    intercept = regress_vals[1]
    r_val = regress_vals[2]
    p_val = regress_vals[3]
    std_error = regress_vals[4]
    
    r2 = r_val ** 2
    
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    regression_dict = {
        'slope': slope,
        'intercept': intercept,
        'r_val': r_val,
        'p_val': p_val,
        'std_error': std_error,
        'r2': r2,
        'line_eq': line_eq }
    return regression_dict

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
north_hem_df = city_data_df[city_data_df['Lat'] >= 0 ]

# Display sample data
north_hem_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            albany  42.6001  -73.9662      5.36        68          78
# 14          stanley  54.8680   -1.6985     11.82        97         100
# 24       constantia  44.1833   28.6500     10.39        78          75
# 33          margate  51.3813    1.3862     13.82        89          98
# 43           laguna  38.4210 -121.4238     22.08        62           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.79      US  1729049637
# 14             3.09      GB  1729049653
# 24             8.92      RO  1729049664
# 33             0.89      GB  1729049461
# 43             2.57      US  1729049686

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
south_hem_df = city_data_df[city_data_df['Lat'] < 0 ]

# Display sample data
south_hem_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        port-aux-francais -49.3500   70.2167      0.60        70          87
# 2                adamstown -25.0660 -130.1015     21.27        88          98
# 3                grytviken -54.2811  -36.5092      3.07        77         100
# 4                  ushuaia -54.8000  -68.3000      5.81        61          40
# 5           puerto natales -51.7236  -72.4875      3.48        92          23
#
#          Wind Speed Country        Date
# City_ID
# 1             16.18      TF  1729049639
# 2              6.71      PN  1729049640
# 3              2.93      GS  1729049641
# 4             11.32      AR  1729049518
# 5              1.80      CL  1729049464

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
ax = north_hem_df.plot.scatter(x = 'Lat', y = 'Max Temp', c = 'DarkBlue', title = 'Northern Hemisphere: Latitude Vs. Temperature')
temp = north_hem_df['Max Temp']
lat = north_hem_df['Lat']
regression_stats = regress(lat, temp)
slope = regression_stats['slope']
intercept = regression_stats['intercept']
r_val = regression_stats['r_val']
p_val = regression_stats['p_val']
std_error = regression_stats['std_error']
r2 = regression_stats['r2']
line_eq = regression_stats['line_eq']
fit = slope * lat + intercept
# Incorporate the other graph properties

ax.set_xlabel('Latitude')
ax.set_ylabel('Temperature')
plt.plot(lat,fit,"r-")
r2_round = f"r^2 = {round(r2,2)}"
plt.annotate(line_eq,(5, -5),fontsize=15,color="red")
plt.annotate(r2_round,(5, -10),fontsize=15,color="red")
print(f"The r-squared value is: {round(r_val ** 2,2)}")
plt.show()
# Out:
# The r-squared value is: 0.77

# %%
# Linear regression on Southern Hemisphere
ax = south_hem_df.plot.scatter(x = 'Lat', y = 'Max Temp', c = 'DarkBlue', title = 'Southern Hemisphere: Latitude Vs. Temperature')
temp = south_hem_df['Max Temp']
lat = south_hem_df['Lat']
regression_stats = regress(lat, temp)
slope = regression_stats['slope']
intercept = regression_stats['intercept']
r_val = regression_stats['r_val']
p_val = regression_stats['p_val']
std_error = regression_stats['std_error']
r2 = regression_stats['r2']
line_eq = regression_stats['line_eq']
fit = slope * lat + intercept

# Incorporate the other graph properties

ax.set_xlabel('Latitude')
ax.set_ylabel('Temperature')
plt.plot(lat,fit,"r-")
r2_round = f"r^2 = {round(r2,2)}"
plt.annotate(line_eq,(-55, 34),fontsize=15,color="red")
plt.annotate(r2_round,(-55, 30),fontsize=15,color="red")
print(f"The r-squared value is: {round(r_val ** 2,2)}")
plt.show()
# Out:
# The r-squared value is: 0.48

# %% [markdown]
# ### ANALYSIS: There is a strong, negative correlation between latitude and temperature in in  the northern hemisphere data (r^2 = 0.77,  meaning latitude explains 77% of the variation in temperature in the the north. There is a moderate, positive correlation between latitude and temperature in the southern hemisphere (r^2 = 0.48, meaning latitude explains only 48%% of the variation in the temperature). This is expected because in the south latitude increses from -90 degrees at the anatric pole, where temeratures are low, to 0 degrees at the tropical equator. Conversly, in the north, latitude and temnperatue are moving in opposite directions; latitude from 0 degrees at the equator (high temperature) to 90 degrees at the atric pole (low temperature).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
ax = north_hem_df.plot.scatter(x = 'Lat', y = 'Humidity', c = 'DarkBlue', title = 'Northern Hemisphere: Latitude Vs. Humidity')
humidity = north_hem_df['Humidity']
lat = north_hem_df['Lat']
regression_stats = regress(lat, humidity)
slope = regression_stats['slope']
intercept = regression_stats['intercept']
r_val = regression_stats['r_val']
p_val = regression_stats['p_val']
std_error = regression_stats['std_error']
r2 = regression_stats['r2']
line_eq = regression_stats['line_eq']
fit = slope * lat + intercept

# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity')
plt.plot(lat,fit,"r-")
r2_round = f"r^2 = {round(r2,2)}"
plt.annotate(line_eq,(45, 27),fontsize=15,color="red")
plt.annotate(r2_round,(45, 21),fontsize=15,color="red")
print(f"The r-squared value is: {round(r_val ** 2,2)}")
plt.show()
# Out:
# The r-squared value is: 0.02

# %%
# Southern Hemisphere
ax = south_hem_df.plot.scatter(x = 'Lat', y = 'Humidity', c = 'DarkBlue', title = 'Southern Hemisphere: Latitude Vs. Humidity')
humidity = south_hem_df['Humidity']
lat = south_hem_df['Lat']
regression_stats = regress(lat, humidity)
slope = regression_stats['slope']
intercept = regression_stats['intercept']
r_val = regression_stats['r_val']
p_val = regression_stats['p_val']
std_error = regression_stats['std_error']
r2 = regression_stats['r2']
line_eq = regression_stats['line_eq']
fit = slope * lat + intercept

# Incorporate the other graph properties

ax.set_xlabel('Latitude')
ax.set_ylabel('Humidity')
plt.plot(lat,fit,"r-")
r2_round = f"r^2 = {round(r2,2)}"
plt.annotate(line_eq,(-55, 28),fontsize=15,color="red")
plt.annotate(r2_round,(-55, 22),fontsize=15,color="red")
print(f"The r-squared value is: {round(r_val ** 2,2)}")
plt.show()
# Out:
# The r-squared value is: 0.01

# %% [markdown]
# ### ANALYSIS: There is no significant correlation between latitude and humidity in either the northern or the southern hemisphere data (north: r^2 = 0.02 and south: r^2 = 0.01, meaning latitude explains only 2% (north) and 1% (south) of the variation in the humidity data)

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
ax = north_hem_df.plot.scatter(x = 'Lat', y = 'Cloudiness', c = 'DarkBlue', title = 'Northern Hemisphere: Latitude Vs. Cloudiness')
cloudiness = north_hem_df['Cloudiness']
lat = north_hem_df['Lat']
regression_stats = regress(lat, cloudiness)
slope = regression_stats['slope']
intercept = regression_stats['intercept']
r_val = regression_stats['r_val']
p_val = regression_stats['p_val']
std_error = regression_stats['std_error']
r2 = regression_stats['r2']
line_eq = regression_stats['line_eq']
fit = slope * lat + intercept

# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness')
plt.plot(lat,fit,"r-")
r2_round = f"r^2 = {round(r2,2)}"
plt.annotate(line_eq,(1, 10),fontsize=15,color="red")
plt.annotate(r2_round,(1, 3),fontsize=15,color="red")
print(f"The r-squared value is: {round(r_val ** 2,2)}")
plt.show()
# Out:
# The r-squared value is: 0.01

# %%
# Southern Hemisphere
ax = south_hem_df.plot.scatter(x = 'Lat', y = 'Cloudiness', c = 'DarkBlue', title = 'Southern Hemisphere: Latitude Vs. Cloudiness')
cloudiness = south_hem_df['Cloudiness']
lat = south_hem_df['Lat']
regression_stats = regress(lat, cloudiness)
slope = regression_stats['slope']
intercept = regression_stats['intercept']
r_val = regression_stats['r_val']
p_val = regression_stats['p_val']
std_error = regression_stats['std_error']
r2 = regression_stats['r2']
line_eq = regression_stats['line_eq']
fit = slope * lat + intercept

# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Cloudiness')
plt.plot(lat,fit,"r-")
r2_round = f"r^2 = {round(r2,2)}"
plt.annotate(line_eq,(-55, 15),fontsize=15,color="red")
plt.annotate(r2_round,(-55, 8),fontsize=15,color="red")
print(f"The r-squared value is: {round(r_val ** 2,2)}")
plt.show()
# Out:
# The r-squared value is: 0.0

# %% [markdown]
# ### ANALYSIS: There is no significant correlation between latitude and cloudines in either the northern or the southern hemisphere data (north: r^2 = 0.01 and south: r^2 = 0.0, meaning latitude explains only 1% (north) and 0% (south) of the variation in the wind speed data)

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
ax = north_hem_df.plot.scatter(x = 'Lat', y = 'Wind Speed', c = 'DarkBlue', title = 'Northern Hemisphere: Latitude Vs. Wind Speed')
wind = north_hem_df['Wind Speed']
lat = north_hem_df['Lat']
regression_stats = regress(lat, wind)
slope = regression_stats['slope']
intercept = regression_stats['intercept']
r_val = regression_stats['r_val']
p_val = regression_stats['p_val']
std_error = regression_stats['std_error']
r2 = regression_stats['r2']
line_eq = regression_stats['line_eq']
fit = slope * lat + intercept

# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed')
plt.plot(lat,fit,"r-")
r2_round = f"r^2 = {round(r2,2)}"
plt.annotate(line_eq,(1, 15),fontsize=15,color="red")
plt.annotate(r2_round,(1, 12),fontsize=15,color="red")
print(f"The r-squared value is: {round(r_val ** 2,2)}")
plt.show()
# Out:
# The r-squared value is: 0.01

# %%
# Southern Hemisphere
ax = south_hem_df.plot.scatter(x = 'Lat', y = 'Wind Speed', c = 'DarkBlue', title = 'Southern Hemisphere: Latitude Vs. Wind Speed')
wind = south_hem_df['Wind Speed']
lat = south_hem_df['Lat']
regression_stats = regress(lat, wind)
slope = regression_stats['slope']
intercept = regression_stats['intercept']
r_val = regression_stats['r_val']
p_val = regression_stats['p_val']
std_error = regression_stats['std_error']
r2 = regression_stats['r2']
line_eq = regression_stats['line_eq']
fit = slope * lat + intercept

# Incorporate the other graph properties
ax.set_xlabel('Latitude')
ax.set_ylabel('Wind Speed')
plt.plot(lat,fit,"r-")
r2_round = f"r^2 = {round(r2,2)}"
plt.annotate(line_eq,(-25, 15),fontsize=15,color="red")
plt.annotate(r2_round,(-25, 13),fontsize=15,color="red")
print(f"The r-squared value is: {round(r_val ** 2,2)}")
plt.show()
# Out:
# The r-squared value is: 0.03

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### ANALYSIS: There is no significant correlation between latitude and wind speed in either the northern or the southern hemisphere data (north: r^2 = 0.01 and south: r^2 = 0.03, meaning latitude explains only 1% (north) and 3% (south) of the variation in the wind speed data)
